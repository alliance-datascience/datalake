# %%
# !pip install "xarray[complete]"==2023.8.0  --user
# !pip install s3fs boto3
# Out:
# Requirement already satisfied: xarray[complete]==2023.8.0 in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (2023.8.0)
# Requirement already satisfied: numpy>=1.21 in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from xarray[complete]==2023.8.0) (1.21.6)
# Requirement already satisfied: pandas>=1.4 in c:\users\cagonzalez\anaconda3\lib\site-packages (from xarray[complete]==2023.8.0) (1.4.4)
# Requirement already satisfied: packaging>=21.3 in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from xarray[complete]==2023.8.0) (23.1)
# Requirement already satisfied: bottleneck in c:\users\cagonzalez\anaconda3\lib\site-packages (from xarray[complete]==2023.8.0) (1.3.5)
# Requirement already satisfied: cftime in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from xarray[complete]==2023.8.0) (1.6.2)
# Requirement already satisfied: dask[complete] in c:\users\cagonzalez\anaconda3\lib\site-packages (from xarray[complete]==2023.8.0) (2022.7.0)
# Requirement already satisfied: zarr in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from xarray[complete]==2023.8.0) (2.16.1)
# Requirement already satisfied: fsspec in c:\users\cagonzalez\anaconda3\lib\site-packages (from xarray[complete]==2023.8.0) (2023.6.0)
# Requirement already satisfied: scipy in c:\users\cagonzalez\anaconda3\lib\site-packages (from xarray[complete]==2023.8.0) (1.9.1)
# Requirement already satisfied: flox in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from xarray[complete]==2023.8.0) (0.7.2)
# Requirement already satisfied: netCDF4 in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from xarray[complete]==2023.8.0) (1.6.4)
# Requirement already satisfied: h5netcdf in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from xarray[complete]==2023.8.0) (1.2.0)
# Requirement already satisfied: matplotlib in c:\users\cagonzalez\anaconda3\lib\site-packages (from xarray[complete]==2023.8.0) (3.5.2)
# Requirement already satisfied: seaborn in c:\users\cagonzalez\anaconda3\lib\site-packages (from xarray[complete]==2023.8.0) (0.11.2)
# Requirement already satisfied: numbagg in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from xarray[complete]==2023.8.0) (0.2.2)
# Requirement already satisfied: nc-time-axis in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from xarray[complete]==2023.8.0) (1.4.1)
# Requirement already satisfied: pydap in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from xarray[complete]==2023.8.0) (3.4.1)
# Requirement already satisfied: pooch in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from xarray[complete]==2023.8.0) (1.7.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from pandas>=1.4->xarray[complete]==2023.8.0) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\cagonzalez\anaconda3\lib\site-packages (from pandas>=1.4->xarray[complete]==2023.8.0) (2.8.2)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\cagonzalez\anaconda3\lib\site-packages (from dask[complete]->xarray[complete]==2023.8.0) (0.11.2)
# Requirement already satisfied: cloudpickle>=1.1.1 in c:\users\cagonzalez\anaconda3\lib\site-packages (from dask[complete]->xarray[complete]==2023.8.0) (2.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from dask[complete]->xarray[complete]==2023.8.0) (6.0.1)
# Requirement already satisfied: partd>=0.3.10 in c:\users\cagonzalez\anaconda3\lib\site-packages (from dask[complete]->xarray[complete]==2023.8.0) (1.2.0)
# Requirement already satisfied: jinja2 in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from dask[complete]->xarray[complete]==2023.8.0) (3.1.2)
# Requirement already satisfied: distributed==2022.7.0 in c:\users\cagonzalez\anaconda3\lib\site-packages (from dask[complete]->xarray[complete]==2023.8.0) (2022.7.0)
# Requirement already satisfied: bokeh>=2.4.2 in c:\users\cagonzalez\anaconda3\lib\site-packages (from dask[complete]->xarray[complete]==2023.8.0) (2.4.3)
# Requirement already satisfied: click>=6.6 in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from distributed==2022.7.0->dask[complete]->xarray[complete]==2023.8.0) (8.1.7)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\cagonzalez\anaconda3\lib\site-packages (from distributed==2022.7.0->dask[complete]->xarray[complete]==2023.8.0) (1.7.0)
# Requirement already satisfied: locket>=1.0.0 in c:\users\cagonzalez\anaconda3\lib\site-packages (from distributed==2022.7.0->dask[complete]->xarray[complete]==2023.8.0) (1.0.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in c:\users\cagonzalez\anaconda3\lib\site-packages (from distributed==2022.7.0->dask[complete]->xarray[complete]==2023.8.0) (2.4.0)
# Requirement already satisfied: tornado<6.2,>=6.0.3 in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from distributed==2022.7.0->dask[complete]->xarray[complete]==2023.8.0) (6.1)
# Requirement already satisfied: psutil>=5.0 in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from distributed==2022.7.0->dask[complete]->xarray[complete]==2023.8.0) (5.9.5)
# Requirement already satisfied: urllib3 in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from distributed==2022.7.0->dask[complete]->xarray[complete]==2023.8.0) (1.26.16)
# Requirement already satisfied: zict>=0.1.3 in c:\users\cagonzalez\anaconda3\lib\site-packages (from distributed==2022.7.0->dask[complete]->xarray[complete]==2023.8.0) (2.1.0)
# Requirement already satisfied: msgpack>=0.6.0 in c:\users\cagonzalez\anaconda3\lib\site-packages (from distributed==2022.7.0->dask[complete]->xarray[complete]==2023.8.0) (1.0.3)
# Requirement already satisfied: numpy-groupies>=0.9.19 in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from flox->xarray[complete]==2023.8.0) (0.9.22)
# Requirement already satisfied: h5py in c:\users\cagonzalez\anaconda3\lib\site-packages (from h5netcdf->xarray[complete]==2023.8.0) (3.7.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cagonzalez\anaconda3\lib\site-packages (from matplotlib->xarray[complete]==2023.8.0) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\cagonzalez\anaconda3\lib\site-packages (from matplotlib->xarray[complete]==2023.8.0) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\cagonzalez\anaconda3\lib\site-packages (from matplotlib->xarray[complete]==2023.8.0) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cagonzalez\anaconda3\lib\site-packages (from matplotlib->xarray[complete]==2023.8.0) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\cagonzalez\anaconda3\lib\site-packages (from matplotlib->xarray[complete]==2023.8.0) (9.2.0)
# Requirement already satisfied: certifi in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from netCDF4->xarray[complete]==2023.8.0) (2023.7.22)
# Requirement already satisfied: numba in c:\users\cagonzalez\anaconda3\lib\site-packages (from numbagg->xarray[complete]==2023.8.0) (0.55.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from pooch->xarray[complete]==2023.8.0) (2.31.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\cagonzalez\anaconda3\lib\site-packages (from pooch->xarray[complete]==2023.8.0) (2.5.2)
# Requirement already satisfied: docopt in c:\users\cagonzalez\anaconda3\lib\site-packages (from pydap->xarray[complete]==2023.8.0) (0.6.2)
# Requirement already satisfied: Webob in c:\users\cagonzalez\anaconda3\lib\site-packages (from pydap->xarray[complete]==2023.8.0) (1.8.7)
# Requirement already satisfied: beautifulsoup4 in c:\users\cagonzalez\anaconda3\lib\site-packages (from pydap->xarray[complete]==2023.8.0) (4.11.1)
# Requirement already satisfied: six>=1.4.0 in c:\users\cagonzalez\anaconda3\lib\site-packages (from pydap->xarray[complete]==2023.8.0) (1.16.0)
# Requirement already satisfied: numcodecs>=0.10.0 in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from zarr->xarray[complete]==2023.8.0) (0.11.0)
# Requirement already satisfied: asciitree in c:\users\cagonzalez\anaconda3\lib\site-packages (from zarr->xarray[complete]==2023.8.0) (0.3.3)
# Requirement already satisfied: fasteners in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from zarr->xarray[complete]==2023.8.0) (0.18)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\cagonzalez\anaconda3\lib\site-packages (from bokeh>=2.4.2->dask[complete]->xarray[complete]==2023.8.0) (4.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from jinja2->dask[complete]->xarray[complete]==2023.8.0) (2.1.3)
# Requirement already satisfied: entrypoints in c:\users\cagonzalez\anaconda3\lib\site-packages (from numcodecs>=0.10.0->zarr->xarray[complete]==2023.8.0) (0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from requests>=2.19.0->pooch->xarray[complete]==2023.8.0) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cagonzalez\appdata\roaming\python\python39\site-packages (from requests>=2.19.0->pooch->xarray[complete]==2023.8.0) (3.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\cagonzalez\anaconda3\lib\site-packages (from beautifulsoup4->pydap->xarray[complete]==2023.8.0) (2.3.1)
# Requirement already satisfied: setuptools in c:\users\cagonzalez\anaconda3\lib\site-packages (from numba->numbagg->xarray[complete]==2023.8.0) (63.4.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\cagonzalez\anaconda3\lib\site-packages (from numba->numbagg->xarray[complete]==2023.8.0) (0.38.0)
# Requirement already satisfied: colorama in c:\users\cagonzalez\anaconda3\lib\site-packages (from click>=6.6->distributed==2022.7.0->dask[complete]->xarray[complete]==2023.8.0) (0.4.6)
# Requirement already satisfied: heapdict in c:\users\cagonzalez\anaconda3\lib\site-packages (from zict>=0.1.3->distributed==2022.7.0->dask[complete]->xarray[complete]==2023.8.0) (1.0.1)

# %%
import xarray as xr
import s3fs
import boto3

# %%
s3ZarrPath = "s3://climate-action-datalake/zone=raw/source=agera5/variable=solarRadiationFlux.zarr/"

# %%
s3 = s3fs.S3FileSystem(key='AKIATHPVGK3ZVLVSHEEF',secret='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')
store = s3fs.S3Map(root=s3ZarrPath, s3=s3, check=False)

# %%
from datetime import datetime
startTime = datetime.now()
africaData=xr.open_zarr(store=store, consolidated=True)
from datetime import datetime
startTime = datetime.now()

# %%
africaMean = africaData.mean(dim = 'time', keep_attrs = True,skipna = True)
africaMean
# Out:
# <xarray.Dataset>
# Dimensions:               (lat: 1801, lon: 3600)
# Coordinates:
#   * lat                   (lat) float64 90.0 89.9 89.8 ... -89.8 -89.9 -90.0
#   * lon                   (lon) float64 -180.0 -179.9 -179.8 ... 179.8 179.9
# Data variables:
#     Solar_Radiation_Flux  (lat, lon) float64 dask.array<chunksize=(1801, 3600), meta=np.ndarray>

# %%
africaMean.to_netcdf('sample.nc')

# %%
africaData.sel(lat=slice(37,-35), lon=slice(-18, 51))
# Out:
# <xarray.Dataset>
# Dimensions:               (time: 15706, lat: 720, lon: 690)
# Coordinates:
#   * lat                   (lat) float64 36.9 36.8 36.7 ... -34.8 -34.9 -35.0
#   * lon                   (lon) float64 -17.9 -17.8 -17.7 ... 50.8 50.9 51.0
#   * time                  (time) datetime64[ns] 1980-01-01 ... 2022-12-31
# Data variables:
#     Solar_Radiation_Flux  (time, lat, lon) float64 dask.array<chunksize=(1, 720, 690), meta=np.ndarray>

# %%
a.reset_index()
# Out:
# Empty DataFrame
# Columns: [time, lat, lon, Solar_Radiation_Flux]
# Index: []
