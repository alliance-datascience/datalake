# %%
# Libraries import
import xarray as xr
import s3fs
import boto3
import pandas as pd
from botocore import UNSIGNED
from botocore.client import Config

# %%
bucketZone='us-east-2'
bucketName='tactical-resume-data'

# %%
s3client = boto3.client('s3', region_name=bucketZone,config=Config(signature_version=UNSIGNED))

# %%
objects = s3client.list_objects(Bucket=bucketName)

# %%
objects
# Out:
# {'ResponseMetadata': {'RequestId': 'RHV1CT6TNY05Q9N0',
#   'HostId': 'jX1AzHaRO4I/3L4aqCW/nAPQsTXHpVkxqKA9IE9kpIKA52Ks7j7QtbWSoEScEu3MS7RejE7+Aa3qcnJcL9H+1w==',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'jX1AzHaRO4I/3L4aqCW/nAPQsTXHpVkxqKA9IE9kpIKA52Ks7j7QtbWSoEScEu3MS7RejE7+Aa3qcnJcL9H+1w==',
#    'x-amz-request-id': 'RHV1CT6TNY05Q9N0',
#    'date': 'Fri, 03 Nov 2023 14:14:24 GMT',
#    'x-amz-bucket-region': 'us-east-2',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'IsTruncated': True,
#  'Marker': '',
#  'Contents': [{'Key': 'futureScenarios/',
#    'LastModified': datetime.datetime(2023, 11, 1, 16, 28, 52, tzinfo=tzutc()),
#    'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#    'Size': 0,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '6ad772314f30acd3306ad459cf37ce77362164551cfb70ec82475722ed73e780'}},
#   {'Key': 'futureScenarios/rainfall/',
# ...
