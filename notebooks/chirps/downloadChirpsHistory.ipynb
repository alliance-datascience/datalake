# %%
import os
import requests
import boto3

# %%
# input_path = "/home/ec2-user/data"
bucket = "climate-action-datalake"
s3_client = boto3.client('s3')

# %%
historical_years = range(2023,2024)
months = range(1,13)
variable_name = ["precipitation"]
url = "https://data.chc.ucsb.edu/products/CHIRPS-2.0/global_daily/tifs/p05"
days=range(1,32)
arrUrl = []
fileFormat = "tif.gz"

# %%
def generate_chirts_URL(years
                         , months
                         ,days
                         ,variables,url
                         ,fileFormat):
    _arrUrl = []
    for _variable in variables:
        for _year in historical_years:
            for _month in months:
                for _day in days:
                    _arrUrl.append(url+"/"+str(_year)+"/"
                                   +f"chirps-v2.0.{_year}.{_month:02d}.{_day:02d}.{fileFormat}")
    return _arrUrl

def download_data(arrUrl,s3_directory,zone,source,variable):
    for _url in arrUrl:
        response = requests.get(_url)
        if response.status_code == 200 :
            file_path = os.path.basename(_url)
#             with open(file_path, 'wb') as file:
#                 for chunk in response.iter_content(chunk_size=1024):
#                     if chunk:
#                         file.write(chunk)
            s3_client.put_object(Bucket=bucket
                                 ,Key=f"zone={zone}/source={source}/variable={variable}/"+file_path
                                 ,Body=response.content
                                )
            print(file_path)

        else:
            print("NOk")

# %%
arrUrl = generate_chirts_URL(historical_years,months,days,variable_name,url,fileFormat)

# %%
"https://data.chc.ucsb.edu/products/CHIRPS-2.0/global_daily/tifs/p05/1981/chirps-v2.0.1981.01.01.tif.gz"
# Out:
# 'https://data.chc.ucsb.edu/products/CHIRPS-2.0/global_daily/tifs/p05/1981/chirps-v2.0.1981.01.01.tif.gz'

# %%
arrUrl[0:2]
# Out:
# ['https://data.chc.ucsb.edu/products/CHIRPS-2.0/global_daily/tifs/p05/2023/chirps-v2.0.2023.01.01.tif.gz',
#  'https://data.chc.ucsb.edu/products/CHIRPS-2.0/global_daily/tifs/p05/2023/chirps-v2.0.2023.01.02.tif.gz']

# %%
download_data(arrUrl,bucket,"landing","CHIRPS","precipitation")
# Out:
# chirps-v2.0.2023.01.01.tif.gz
# chirps-v2.0.2023.01.02.tif.gz
# chirps-v2.0.2023.01.03.tif.gz
# chirps-v2.0.2023.01.04.tif.gz
# chirps-v2.0.2023.01.05.tif.gz
# chirps-v2.0.2023.01.06.tif.gz
# chirps-v2.0.2023.01.07.tif.gz
# chirps-v2.0.2023.01.08.tif.gz
# chirps-v2.0.2023.01.09.tif.gz
# chirps-v2.0.2023.01.10.tif.gz
# chirps-v2.0.2023.01.11.tif.gz
# chirps-v2.0.2023.01.12.tif.gz
# chirps-v2.0.2023.01.13.tif.gz
# chirps-v2.0.2023.01.14.tif.gz
# chirps-v2.0.2023.01.15.tif.gz
# chirps-v2.0.2023.01.16.tif.gz
# chirps-v2.0.2023.01.17.tif.gz
# chirps-v2.0.2023.01.18.tif.gz
# chirps-v2.0.2023.01.19.tif.gz
# chirps-v2.0.2023.01.20.tif.gz
# chirps-v2.0.2023.01.21.tif.gz
# chirps-v2.0.2023.01.22.tif.gz
# chirps-v2.0.2023.01.23.tif.gz
# chirps-v2.0.2023.01.24.tif.gz
# chirps-v2.0.2023.01.25.tif.gz
# chirps-v2.0.2023.01.26.tif.gz
# chirps-v2.0.2023.01.27.tif.gz
# chirps-v2.0.2023.01.28.tif.gz
# chirps-v2.0.2023.01.29.tif.gz
# chirps-v2.0.2023.01.30.tif.gz
# chirps-v2.0.2023.01.31.tif.gz
# chirps-v2.0.2023.02.01.tif.gz
# chirps-v2.0.2023.02.02.tif.gz
# chirps-v2.0.2023.02.03.tif.gz
# chirps-v2.0.2023.02.04.tif.gz
# chirps-v2.0.2023.02.05.tif.gz
# chirps-v2.0.2023.02.06.tif.gz
# chirps-v2.0.2023.02.07.tif.gz
# chirps-v2.0.2023.02.08.tif.gz
# chirps-v2.0.2023.02.09.tif.gz
# chirps-v2.0.2023.02.10.tif.gz
# chirps-v2.0.2023.02.11.tif.gz
# chirps-v2.0.2023.02.12.tif.gz
# chirps-v2.0.2023.02.13.tif.gz
# chirps-v2.0.2023.02.14.tif.gz
# chirps-v2.0.2023.02.15.tif.gz
# chirps-v2.0.2023.02.16.tif.gz
# chirps-v2.0.2023.02.17.tif.gz
# chirps-v2.0.2023.02.18.tif.gz
# chirps-v2.0.2023.02.19.tif.gz
# chirps-v2.0.2023.02.20.tif.gz
# chirps-v2.0.2023.02.21.tif.gz
# chirps-v2.0.2023.02.22.tif.gz
# chirps-v2.0.2023.02.23.tif.gz
# chirps-v2.0.2023.02.24.tif.gz
# chirps-v2.0.2023.02.25.tif.gz
# chirps-v2.0.2023.02.26.tif.gz
# chirps-v2.0.2023.02.27.tif.gz
# chirps-v2.0.2023.02.28.tif.gz
# NOk
# NOk
# NOk
# chirps-v2.0.2023.03.01.tif.gz
# chirps-v2.0.2023.03.02.tif.gz
# chirps-v2.0.2023.03.03.tif.gz
# chirps-v2.0.2023.03.04.tif.gz
# chirps-v2.0.2023.03.05.tif.gz
# chirps-v2.0.2023.03.06.tif.gz
# chirps-v2.0.2023.03.07.tif.gz
# chirps-v2.0.2023.03.08.tif.gz
# chirps-v2.0.2023.03.09.tif.gz
# chirps-v2.0.2023.03.10.tif.gz
# chirps-v2.0.2023.03.11.tif.gz
# chirps-v2.0.2023.03.12.tif.gz
# chirps-v2.0.2023.03.13.tif.gz
# chirps-v2.0.2023.03.14.tif.gz
# chirps-v2.0.2023.03.15.tif.gz
# chirps-v2.0.2023.03.16.tif.gz
# chirps-v2.0.2023.03.17.tif.gz
# chirps-v2.0.2023.03.18.tif.gz
# chirps-v2.0.2023.03.19.tif.gz
# chirps-v2.0.2023.03.20.tif.gz
# chirps-v2.0.2023.03.21.tif.gz
# chirps-v2.0.2023.03.22.tif.gz
# chirps-v2.0.2023.03.23.tif.gz
# chirps-v2.0.2023.03.24.tif.gz
# chirps-v2.0.2023.03.25.tif.gz
# chirps-v2.0.2023.03.26.tif.gz
# chirps-v2.0.2023.03.27.tif.gz
# chirps-v2.0.2023.03.28.tif.gz
# chirps-v2.0.2023.03.29.tif.gz
# chirps-v2.0.2023.03.30.tif.gz
# chirps-v2.0.2023.03.31.tif.gz
# chirps-v2.0.2023.04.01.tif.gz
# chirps-v2.0.2023.04.02.tif.gz
# chirps-v2.0.2023.04.03.tif.gz
# chirps-v2.0.2023.04.04.tif.gz
# chirps-v2.0.2023.04.05.tif.gz
# chirps-v2.0.2023.04.06.tif.gz
# chirps-v2.0.2023.04.07.tif.gz
# chirps-v2.0.2023.04.08.tif.gz
# chirps-v2.0.2023.04.09.tif.gz
# chirps-v2.0.2023.04.10.tif.gz
# chirps-v2.0.2023.04.11.tif.gz
# chirps-v2.0.2023.04.12.tif.gz
# chirps-v2.0.2023.04.13.tif.gz
# chirps-v2.0.2023.04.14.tif.gz
# chirps-v2.0.2023.04.15.tif.gz
# chirps-v2.0.2023.04.16.tif.gz
# chirps-v2.0.2023.04.17.tif.gz
# chirps-v2.0.2023.04.18.tif.gz
# chirps-v2.0.2023.04.19.tif.gz
# chirps-v2.0.2023.04.20.tif.gz
# chirps-v2.0.2023.04.21.tif.gz
# chirps-v2.0.2023.04.22.tif.gz
# chirps-v2.0.2023.04.23.tif.gz
# chirps-v2.0.2023.04.24.tif.gz
# chirps-v2.0.2023.04.25.tif.gz
# chirps-v2.0.2023.04.26.tif.gz
# chirps-v2.0.2023.04.27.tif.gz
# chirps-v2.0.2023.04.28.tif.gz
# chirps-v2.0.2023.04.29.tif.gz
# chirps-v2.0.2023.04.30.tif.gz
# NOk
# chirps-v2.0.2023.05.01.tif.gz
# chirps-v2.0.2023.05.02.tif.gz
# chirps-v2.0.2023.05.03.tif.gz
# chirps-v2.0.2023.05.04.tif.gz
# chirps-v2.0.2023.05.05.tif.gz
# chirps-v2.0.2023.05.06.tif.gz
# chirps-v2.0.2023.05.07.tif.gz
# chirps-v2.0.2023.05.08.tif.gz
# chirps-v2.0.2023.05.09.tif.gz
# chirps-v2.0.2023.05.10.tif.gz
# chirps-v2.0.2023.05.11.tif.gz
# chirps-v2.0.2023.05.12.tif.gz
# chirps-v2.0.2023.05.13.tif.gz
# chirps-v2.0.2023.05.14.tif.gz
# chirps-v2.0.2023.05.15.tif.gz
# chirps-v2.0.2023.05.16.tif.gz
# chirps-v2.0.2023.05.17.tif.gz
# chirps-v2.0.2023.05.18.tif.gz
# chirps-v2.0.2023.05.19.tif.gz
# chirps-v2.0.2023.05.20.tif.gz
# chirps-v2.0.2023.05.21.tif.gz
# chirps-v2.0.2023.05.22.tif.gz
# chirps-v2.0.2023.05.23.tif.gz
# chirps-v2.0.2023.05.24.tif.gz
# chirps-v2.0.2023.05.25.tif.gz
# chirps-v2.0.2023.05.26.tif.gz
# chirps-v2.0.2023.05.27.tif.gz
# chirps-v2.0.2023.05.28.tif.gz
# chirps-v2.0.2023.05.29.tif.gz
# chirps-v2.0.2023.05.30.tif.gz
# chirps-v2.0.2023.05.31.tif.gz
# chirps-v2.0.2023.06.01.tif.gz
# chirps-v2.0.2023.06.02.tif.gz
# chirps-v2.0.2023.06.03.tif.gz
# chirps-v2.0.2023.06.04.tif.gz
# chirps-v2.0.2023.06.05.tif.gz
# chirps-v2.0.2023.06.06.tif.gz
# chirps-v2.0.2023.06.07.tif.gz
# chirps-v2.0.2023.06.08.tif.gz
# chirps-v2.0.2023.06.09.tif.gz
# chirps-v2.0.2023.06.10.tif.gz
# chirps-v2.0.2023.06.11.tif.gz
# chirps-v2.0.2023.06.12.tif.gz
# chirps-v2.0.2023.06.13.tif.gz
# chirps-v2.0.2023.06.14.tif.gz
# chirps-v2.0.2023.06.15.tif.gz
# chirps-v2.0.2023.06.16.tif.gz
# chirps-v2.0.2023.06.17.tif.gz
# chirps-v2.0.2023.06.18.tif.gz
# chirps-v2.0.2023.06.19.tif.gz
# chirps-v2.0.2023.06.20.tif.gz
# chirps-v2.0.2023.06.21.tif.gz
# chirps-v2.0.2023.06.22.tif.gz
# chirps-v2.0.2023.06.23.tif.gz
# chirps-v2.0.2023.06.24.tif.gz
# chirps-v2.0.2023.06.25.tif.gz
# chirps-v2.0.2023.06.26.tif.gz
# chirps-v2.0.2023.06.27.tif.gz
# chirps-v2.0.2023.06.28.tif.gz
# chirps-v2.0.2023.06.29.tif.gz
# chirps-v2.0.2023.06.30.tif.gz
# NOk
# chirps-v2.0.2023.07.01.tif.gz
# chirps-v2.0.2023.07.02.tif.gz
# chirps-v2.0.2023.07.03.tif.gz
# chirps-v2.0.2023.07.04.tif.gz
# chirps-v2.0.2023.07.05.tif.gz
# chirps-v2.0.2023.07.06.tif.gz
# chirps-v2.0.2023.07.07.tif.gz
# chirps-v2.0.2023.07.08.tif.gz
# chirps-v2.0.2023.07.09.tif.gz
# chirps-v2.0.2023.07.10.tif.gz
# chirps-v2.0.2023.07.11.tif.gz
# chirps-v2.0.2023.07.12.tif.gz
# chirps-v2.0.2023.07.13.tif.gz
# chirps-v2.0.2023.07.14.tif.gz
# chirps-v2.0.2023.07.15.tif.gz
# chirps-v2.0.2023.07.16.tif.gz
# chirps-v2.0.2023.07.17.tif.gz
# chirps-v2.0.2023.07.18.tif.gz
# chirps-v2.0.2023.07.19.tif.gz
# chirps-v2.0.2023.07.20.tif.gz
# chirps-v2.0.2023.07.21.tif.gz
# chirps-v2.0.2023.07.22.tif.gz
# chirps-v2.0.2023.07.23.tif.gz
# chirps-v2.0.2023.07.24.tif.gz
# chirps-v2.0.2023.07.25.tif.gz
# chirps-v2.0.2023.07.26.tif.gz
# chirps-v2.0.2023.07.27.tif.gz
# chirps-v2.0.2023.07.28.tif.gz
# chirps-v2.0.2023.07.29.tif.gz
# chirps-v2.0.2023.07.30.tif.gz
# chirps-v2.0.2023.07.31.tif.gz
# chirps-v2.0.2023.08.01.tif.gz
# chirps-v2.0.2023.08.02.tif.gz
# chirps-v2.0.2023.08.03.tif.gz
# chirps-v2.0.2023.08.04.tif.gz
# chirps-v2.0.2023.08.05.tif.gz
# chirps-v2.0.2023.08.06.tif.gz
# chirps-v2.0.2023.08.07.tif.gz
# chirps-v2.0.2023.08.08.tif.gz
# chirps-v2.0.2023.08.09.tif.gz
# chirps-v2.0.2023.08.10.tif.gz
# chirps-v2.0.2023.08.11.tif.gz
# chirps-v2.0.2023.08.12.tif.gz
# chirps-v2.0.2023.08.13.tif.gz
# chirps-v2.0.2023.08.14.tif.gz
# chirps-v2.0.2023.08.15.tif.gz
# chirps-v2.0.2023.08.16.tif.gz
# chirps-v2.0.2023.08.17.tif.gz
# chirps-v2.0.2023.08.18.tif.gz
# chirps-v2.0.2023.08.19.tif.gz
# chirps-v2.0.2023.08.20.tif.gz
# chirps-v2.0.2023.08.21.tif.gz
# chirps-v2.0.2023.08.22.tif.gz
# chirps-v2.0.2023.08.23.tif.gz
# chirps-v2.0.2023.08.24.tif.gz
# chirps-v2.0.2023.08.25.tif.gz
# chirps-v2.0.2023.08.26.tif.gz
# chirps-v2.0.2023.08.27.tif.gz
# chirps-v2.0.2023.08.28.tif.gz
# chirps-v2.0.2023.08.29.tif.gz
# chirps-v2.0.2023.08.30.tif.gz
# chirps-v2.0.2023.08.31.tif.gz
# chirps-v2.0.2023.09.01.tif.gz
# chirps-v2.0.2023.09.02.tif.gz
# chirps-v2.0.2023.09.03.tif.gz
# chirps-v2.0.2023.09.04.tif.gz
# chirps-v2.0.2023.09.05.tif.gz
# chirps-v2.0.2023.09.06.tif.gz
# chirps-v2.0.2023.09.07.tif.gz
# chirps-v2.0.2023.09.08.tif.gz
# chirps-v2.0.2023.09.09.tif.gz
# chirps-v2.0.2023.09.10.tif.gz
# chirps-v2.0.2023.09.11.tif.gz
# chirps-v2.0.2023.09.12.tif.gz
# chirps-v2.0.2023.09.13.tif.gz
# chirps-v2.0.2023.09.14.tif.gz
# chirps-v2.0.2023.09.15.tif.gz
# chirps-v2.0.2023.09.16.tif.gz
# chirps-v2.0.2023.09.17.tif.gz
# chirps-v2.0.2023.09.18.tif.gz
# chirps-v2.0.2023.09.19.tif.gz
# chirps-v2.0.2023.09.20.tif.gz
# chirps-v2.0.2023.09.21.tif.gz
# chirps-v2.0.2023.09.22.tif.gz
# chirps-v2.0.2023.09.23.tif.gz
# chirps-v2.0.2023.09.24.tif.gz
# chirps-v2.0.2023.09.25.tif.gz
# chirps-v2.0.2023.09.26.tif.gz
# chirps-v2.0.2023.09.27.tif.gz
# chirps-v2.0.2023.09.28.tif.gz
# chirps-v2.0.2023.09.29.tif.gz
# chirps-v2.0.2023.09.30.tif.gz
# NOk
# chirps-v2.0.2023.10.01.tif.gz
# chirps-v2.0.2023.10.02.tif.gz
# chirps-v2.0.2023.10.03.tif.gz
# chirps-v2.0.2023.10.04.tif.gz
# chirps-v2.0.2023.10.05.tif.gz
# chirps-v2.0.2023.10.06.tif.gz
# chirps-v2.0.2023.10.07.tif.gz
# chirps-v2.0.2023.10.08.tif.gz
# chirps-v2.0.2023.10.09.tif.gz
# chirps-v2.0.2023.10.10.tif.gz
# chirps-v2.0.2023.10.11.tif.gz
# chirps-v2.0.2023.10.12.tif.gz
# chirps-v2.0.2023.10.13.tif.gz
# chirps-v2.0.2023.10.14.tif.gz
# chirps-v2.0.2023.10.15.tif.gz
# chirps-v2.0.2023.10.16.tif.gz
# chirps-v2.0.2023.10.17.tif.gz
# chirps-v2.0.2023.10.18.tif.gz
# chirps-v2.0.2023.10.19.tif.gz
# chirps-v2.0.2023.10.20.tif.gz
# chirps-v2.0.2023.10.21.tif.gz
# chirps-v2.0.2023.10.22.tif.gz
# chirps-v2.0.2023.10.23.tif.gz
# chirps-v2.0.2023.10.24.tif.gz
# chirps-v2.0.2023.10.25.tif.gz
# chirps-v2.0.2023.10.26.tif.gz
# chirps-v2.0.2023.10.27.tif.gz
# chirps-v2.0.2023.10.28.tif.gz
# chirps-v2.0.2023.10.29.tif.gz
# chirps-v2.0.2023.10.30.tif.gz
# chirps-v2.0.2023.10.31.tif.gz
# chirps-v2.0.2023.11.01.tif.gz
# chirps-v2.0.2023.11.02.tif.gz
# chirps-v2.0.2023.11.03.tif.gz
# chirps-v2.0.2023.11.04.tif.gz
# chirps-v2.0.2023.11.05.tif.gz
# chirps-v2.0.2023.11.06.tif.gz
# chirps-v2.0.2023.11.07.tif.gz
# chirps-v2.0.2023.11.08.tif.gz
# chirps-v2.0.2023.11.09.tif.gz
# chirps-v2.0.2023.11.10.tif.gz
# chirps-v2.0.2023.11.11.tif.gz
# chirps-v2.0.2023.11.12.tif.gz
# chirps-v2.0.2023.11.13.tif.gz
# chirps-v2.0.2023.11.14.tif.gz
# chirps-v2.0.2023.11.15.tif.gz
# chirps-v2.0.2023.11.16.tif.gz
# chirps-v2.0.2023.11.17.tif.gz
# chirps-v2.0.2023.11.18.tif.gz
# chirps-v2.0.2023.11.19.tif.gz
# chirps-v2.0.2023.11.20.tif.gz
# chirps-v2.0.2023.11.21.tif.gz
# chirps-v2.0.2023.11.22.tif.gz
# chirps-v2.0.2023.11.23.tif.gz
# chirps-v2.0.2023.11.24.tif.gz
# chirps-v2.0.2023.11.25.tif.gz
# chirps-v2.0.2023.11.26.tif.gz
# chirps-v2.0.2023.11.27.tif.gz
# chirps-v2.0.2023.11.28.tif.gz
# chirps-v2.0.2023.11.29.tif.gz
# chirps-v2.0.2023.11.30.tif.gz
# NOk
# chirps-v2.0.2023.12.01.tif.gz
# chirps-v2.0.2023.12.02.tif.gz
# chirps-v2.0.2023.12.03.tif.gz
# chirps-v2.0.2023.12.04.tif.gz
# chirps-v2.0.2023.12.05.tif.gz
# chirps-v2.0.2023.12.06.tif.gz
# chirps-v2.0.2023.12.07.tif.gz
# chirps-v2.0.2023.12.08.tif.gz
# chirps-v2.0.2023.12.09.tif.gz
# chirps-v2.0.2023.12.10.tif.gz
# chirps-v2.0.2023.12.11.tif.gz
# chirps-v2.0.2023.12.12.tif.gz
# chirps-v2.0.2023.12.13.tif.gz
# chirps-v2.0.2023.12.14.tif.gz
# chirps-v2.0.2023.12.15.tif.gz
# chirps-v2.0.2023.12.16.tif.gz
# chirps-v2.0.2023.12.17.tif.gz
# chirps-v2.0.2023.12.18.tif.gz
# chirps-v2.0.2023.12.19.tif.gz
# chirps-v2.0.2023.12.20.tif.gz
# chirps-v2.0.2023.12.21.tif.gz
# chirps-v2.0.2023.12.22.tif.gz
# chirps-v2.0.2023.12.23.tif.gz
# chirps-v2.0.2023.12.24.tif.gz
# chirps-v2.0.2023.12.25.tif.gz
# chirps-v2.0.2023.12.26.tif.gz
# chirps-v2.0.2023.12.27.tif.gz
# chirps-v2.0.2023.12.28.tif.gz
# chirps-v2.0.2023.12.29.tif.gz
# chirps-v2.0.2023.12.30.tif.gz
# chirps-v2.0.2023.12.31.tif.gz
