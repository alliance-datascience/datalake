# %%
import os
import requests
import boto3

# %%
# input_path = "/home/ec2-user/data"
bucket = "climate-action-datalake"

s3_client = boto3.client('s3')

# %%
historical_years = range(1981,2024)
months = range(1,13)
variable_name = ["precipitation"]
url = "https://data.chc.ucsb.edu/products/CHIRPS-2.0/global_daily/tifs/p05"
days=range(1,32)
arrUrl = []
fileFormat = "tif.gz"

# %%
def generate_chirts_URL(years
                         , months
                         ,days
                         ,variables,url
                         ,fileFormat):
    _arrUrl = []
    for _variable in variables:
        for _year in historical_years:
            for _month in months:
                for _day in days:
                    _arrUrl.append(url+"/"+str(_year)+"/"
                                   +f"chirps-v2.0.{_year}.{_month:02d}.{_day:02d}.{fileFormat}")
    return _arrUrl

def download_data(arrUrl,s3_directory,zone,source,variable):
    for _url in arrUrl:
        response = requests.get(_url)
        if response.status_code == 200 :
            file_path = os.path.basename(_url)
#             with open(file_path, 'wb') as file:
#                 for chunk in response.iter_content(chunk_size=1024):
#                     if chunk:
#                         file.write(chunk)
            s3_client.put_object(Bucket=bucket
                                 ,Key=f"zone={zone}/source={source}/variable={variable}/"+file_path
                                 ,Body=response.content
                                )
            print(file_path)

        else:
            print("NOk")

# %%
arrUrl = generate_chirts_URL(historical_years,months,days,variable_name,url,fileFormat)

# %%
"https://data.chc.ucsb.edu/products/CHIRPS-2.0/global_daily/tifs/p05/1981/chirps-v2.0.1981.01.01.tif.gz"
# Out:
# 'https://data.chc.ucsb.edu/products/CHIRPS-2.0/global_daily/tifs/p05/1981/chirps-v2.0.1981.01.01.tif.gz'

# %%
arrUrl[0:2]
# Out:
# ['https://data.chc.ucsb.edu/products/CHIRPS-2.0/global_daily/tifs/p05/1981/chirps-v2.0.1981.01.01.tif.gz',
#  'https://data.chc.ucsb.edu/products/CHIRPS-2.0/global_daily/tifs/p05/1981/chirps-v2.0.1981.01.02.tif.gz']

# %%
download_data(arrUrl,bucket,"landing","CHIRPS","precipitation")
# Out:
# chirps-v2.0.1981.01.01.tif.gz
# chirps-v2.0.1981.01.02.tif.gz
# chirps-v2.0.1981.01.03.tif.gz
# chirps-v2.0.1981.01.04.tif.gz
# chirps-v2.0.1981.01.05.tif.gz
# chirps-v2.0.1981.01.06.tif.gz
# chirps-v2.0.1981.01.07.tif.gz
# chirps-v2.0.1981.01.08.tif.gz
# chirps-v2.0.1981.01.09.tif.gz
# chirps-v2.0.1981.01.10.tif.gz
# chirps-v2.0.1981.01.11.tif.gz
# chirps-v2.0.1981.01.12.tif.gz
# chirps-v2.0.1981.01.13.tif.gz
# chirps-v2.0.1981.01.14.tif.gz
# chirps-v2.0.1981.01.15.tif.gz
# chirps-v2.0.1981.01.16.tif.gz
# chirps-v2.0.1981.01.17.tif.gz
# chirps-v2.0.1981.01.18.tif.gz
# chirps-v2.0.1981.01.19.tif.gz
# chirps-v2.0.1981.01.20.tif.gz
# chirps-v2.0.1981.01.21.tif.gz
# chirps-v2.0.1981.01.22.tif.gz
# chirps-v2.0.1981.01.23.tif.gz
# chirps-v2.0.1981.01.24.tif.gz
# chirps-v2.0.1981.01.25.tif.gz
# chirps-v2.0.1981.01.26.tif.gz
# chirps-v2.0.1981.01.27.tif.gz
# chirps-v2.0.1981.01.28.tif.gz
# chirps-v2.0.1981.01.29.tif.gz
# chirps-v2.0.1981.01.30.tif.gz
# chirps-v2.0.1981.01.31.tif.gz
# chirps-v2.0.1981.02.01.tif.gz
# chirps-v2.0.1981.02.02.tif.gz
# chirps-v2.0.1981.02.03.tif.gz
# chirps-v2.0.1981.02.04.tif.gz
# chirps-v2.0.1981.02.05.tif.gz
# chirps-v2.0.1981.02.06.tif.gz
# chirps-v2.0.1981.02.07.tif.gz
# chirps-v2.0.1981.02.08.tif.gz
# chirps-v2.0.1981.02.09.tif.gz
# chirps-v2.0.1981.02.10.tif.gz
# chirps-v2.0.1981.02.11.tif.gz
# chirps-v2.0.1981.02.12.tif.gz
# chirps-v2.0.1981.02.13.tif.gz
# chirps-v2.0.1981.02.14.tif.gz
# chirps-v2.0.1981.02.15.tif.gz
# chirps-v2.0.1981.02.16.tif.gz
# chirps-v2.0.1981.02.17.tif.gz
# chirps-v2.0.1981.02.18.tif.gz
# chirps-v2.0.1981.02.19.tif.gz
# chirps-v2.0.1981.02.20.tif.gz
# chirps-v2.0.1981.02.21.tif.gz
# chirps-v2.0.1981.02.22.tif.gz
# chirps-v2.0.1981.02.23.tif.gz
# chirps-v2.0.1981.02.24.tif.gz
# chirps-v2.0.1981.02.25.tif.gz
# chirps-v2.0.1981.02.26.tif.gz
# chirps-v2.0.1981.02.27.tif.gz
# chirps-v2.0.1981.02.28.tif.gz
# NOk
# NOk
# NOk
# chirps-v2.0.1981.03.01.tif.gz
# chirps-v2.0.1981.03.02.tif.gz
# chirps-v2.0.1981.03.03.tif.gz
# chirps-v2.0.1981.03.04.tif.gz
# chirps-v2.0.1981.03.05.tif.gz
# chirps-v2.0.1981.03.06.tif.gz
# chirps-v2.0.1981.03.07.tif.gz
# chirps-v2.0.1981.03.08.tif.gz
# chirps-v2.0.1981.03.09.tif.gz
# chirps-v2.0.1981.03.10.tif.gz
# chirps-v2.0.1981.03.11.tif.gz
# chirps-v2.0.1981.03.12.tif.gz
# chirps-v2.0.1981.03.13.tif.gz
# chirps-v2.0.1981.03.14.tif.gz
# chirps-v2.0.1981.03.15.tif.gz
# chirps-v2.0.1981.03.16.tif.gz
# chirps-v2.0.1981.03.17.tif.gz
# chirps-v2.0.1981.03.18.tif.gz
# chirps-v2.0.1981.03.19.tif.gz
# chirps-v2.0.1981.03.20.tif.gz
# chirps-v2.0.1981.03.21.tif.gz
# chirps-v2.0.1981.03.22.tif.gz
# chirps-v2.0.1981.03.23.tif.gz
# chirps-v2.0.1981.03.24.tif.gz
# chirps-v2.0.1981.03.25.tif.gz
# chirps-v2.0.1981.03.26.tif.gz
# chirps-v2.0.1981.03.27.tif.gz
# chirps-v2.0.1981.03.28.tif.gz
# chirps-v2.0.1981.03.29.tif.gz
# chirps-v2.0.1981.03.30.tif.gz
# chirps-v2.0.1981.03.31.tif.gz
# chirps-v2.0.1981.04.01.tif.gz
# chirps-v2.0.1981.04.02.tif.gz
# chirps-v2.0.1981.04.03.tif.gz
# chirps-v2.0.1981.04.04.tif.gz
# chirps-v2.0.1981.04.05.tif.gz
# chirps-v2.0.1981.04.06.tif.gz
# chirps-v2.0.1981.04.07.tif.gz
# chirps-v2.0.1981.04.08.tif.gz
# chirps-v2.0.1981.04.09.tif.gz
# chirps-v2.0.1981.04.10.tif.gz
# chirps-v2.0.1981.04.11.tif.gz
# chirps-v2.0.1981.04.12.tif.gz
# chirps-v2.0.1981.04.13.tif.gz
# chirps-v2.0.1981.04.14.tif.gz
# chirps-v2.0.1981.04.15.tif.gz
# chirps-v2.0.1981.04.16.tif.gz
# chirps-v2.0.1981.04.17.tif.gz
# chirps-v2.0.1981.04.18.tif.gz
# chirps-v2.0.1981.04.19.tif.gz
# chirps-v2.0.1981.04.20.tif.gz
# chirps-v2.0.1981.04.21.tif.gz
# chirps-v2.0.1981.04.22.tif.gz
# chirps-v2.0.1981.04.23.tif.gz
# chirps-v2.0.1981.04.24.tif.gz
# chirps-v2.0.1981.04.25.tif.gz
# chirps-v2.0.1981.04.26.tif.gz
# chirps-v2.0.1981.04.27.tif.gz
# chirps-v2.0.1981.04.28.tif.gz
# chirps-v2.0.1981.04.29.tif.gz
# chirps-v2.0.1981.04.30.tif.gz
# NOk
# chirps-v2.0.1981.05.01.tif.gz
# chirps-v2.0.1981.05.02.tif.gz
# chirps-v2.0.1981.05.03.tif.gz
# chirps-v2.0.1981.05.04.tif.gz
# chirps-v2.0.1981.05.05.tif.gz
# chirps-v2.0.1981.05.06.tif.gz
# chirps-v2.0.1981.05.07.tif.gz
# chirps-v2.0.1981.05.08.tif.gz
# chirps-v2.0.1981.05.09.tif.gz
# chirps-v2.0.1981.05.10.tif.gz
# chirps-v2.0.1981.05.11.tif.gz
# chirps-v2.0.1981.05.12.tif.gz
# chirps-v2.0.1981.05.13.tif.gz
# chirps-v2.0.1981.05.14.tif.gz
# chirps-v2.0.1981.05.15.tif.gz
# chirps-v2.0.1981.05.16.tif.gz
# chirps-v2.0.1981.05.17.tif.gz
# chirps-v2.0.1981.05.18.tif.gz
# chirps-v2.0.1981.05.19.tif.gz
# chirps-v2.0.1981.05.20.tif.gz
# chirps-v2.0.1981.05.21.tif.gz
# chirps-v2.0.1981.05.22.tif.gz
# chirps-v2.0.1981.05.23.tif.gz
# chirps-v2.0.1981.05.24.tif.gz
# chirps-v2.0.1981.05.25.tif.gz
# chirps-v2.0.1981.05.26.tif.gz
# chirps-v2.0.1981.05.27.tif.gz
# chirps-v2.0.1981.05.28.tif.gz
# chirps-v2.0.1981.05.29.tif.gz
# chirps-v2.0.1981.05.30.tif.gz
# chirps-v2.0.1981.05.31.tif.gz
# chirps-v2.0.1981.06.01.tif.gz
# chirps-v2.0.1981.06.02.tif.gz
# chirps-v2.0.1981.06.03.tif.gz
# chirps-v2.0.1981.06.04.tif.gz
# chirps-v2.0.1981.06.05.tif.gz
# chirps-v2.0.1981.06.06.tif.gz
# chirps-v2.0.1981.06.07.tif.gz
# chirps-v2.0.1981.06.08.tif.gz
# chirps-v2.0.1981.06.09.tif.gz
# chirps-v2.0.1981.06.10.tif.gz
# chirps-v2.0.1981.06.11.tif.gz
# chirps-v2.0.1981.06.12.tif.gz
# chirps-v2.0.1981.06.13.tif.gz
# chirps-v2.0.1981.06.14.tif.gz
# chirps-v2.0.1981.06.15.tif.gz
# chirps-v2.0.1981.06.16.tif.gz
# chirps-v2.0.1981.06.17.tif.gz
# chirps-v2.0.1981.06.18.tif.gz
# chirps-v2.0.1981.06.19.tif.gz
# chirps-v2.0.1981.06.20.tif.gz
# chirps-v2.0.1981.06.21.tif.gz
# chirps-v2.0.1981.06.22.tif.gz
# chirps-v2.0.1981.06.23.tif.gz
# chirps-v2.0.1981.06.24.tif.gz
# chirps-v2.0.1981.06.25.tif.gz
# chirps-v2.0.1981.06.26.tif.gz
# chirps-v2.0.1981.06.27.tif.gz
# chirps-v2.0.1981.06.28.tif.gz
# chirps-v2.0.1981.06.29.tif.gz
# chirps-v2.0.1981.06.30.tif.gz
# NOk
# chirps-v2.0.1981.07.01.tif.gz
# chirps-v2.0.1981.07.02.tif.gz
# chirps-v2.0.1981.07.03.tif.gz
# chirps-v2.0.1981.07.04.tif.gz
# chirps-v2.0.1981.07.05.tif.gz
# chirps-v2.0.1981.07.06.tif.gz
# chirps-v2.0.1981.07.07.tif.gz
# chirps-v2.0.1981.07.08.tif.gz
# chirps-v2.0.1981.07.09.tif.gz
# chirps-v2.0.1981.07.10.tif.gz
# chirps-v2.0.1981.07.11.tif.gz
# chirps-v2.0.1981.07.12.tif.gz
# chirps-v2.0.1981.07.13.tif.gz
# chirps-v2.0.1981.07.14.tif.gz
# chirps-v2.0.1981.07.15.tif.gz
# chirps-v2.0.1981.07.16.tif.gz
# chirps-v2.0.1981.07.17.tif.gz
# chirps-v2.0.1981.07.18.tif.gz
# chirps-v2.0.1981.07.19.tif.gz
# chirps-v2.0.1981.07.20.tif.gz
# chirps-v2.0.1981.07.21.tif.gz
# chirps-v2.0.1981.07.22.tif.gz
# chirps-v2.0.1981.07.23.tif.gz
# chirps-v2.0.1981.07.24.tif.gz
# chirps-v2.0.1981.07.25.tif.gz
# chirps-v2.0.1981.07.26.tif.gz
# chirps-v2.0.1981.07.27.tif.gz
# chirps-v2.0.1981.07.28.tif.gz
# chirps-v2.0.1981.07.29.tif.gz
# chirps-v2.0.1981.07.30.tif.gz
# chirps-v2.0.1981.07.31.tif.gz
# chirps-v2.0.1981.08.01.tif.gz
# chirps-v2.0.1981.08.02.tif.gz
# chirps-v2.0.1981.08.03.tif.gz
# chirps-v2.0.1981.08.04.tif.gz
# chirps-v2.0.1981.08.05.tif.gz
# chirps-v2.0.1981.08.06.tif.gz
# chirps-v2.0.1981.08.07.tif.gz
# chirps-v2.0.1981.08.08.tif.gz
# chirps-v2.0.1981.08.09.tif.gz
# chirps-v2.0.1981.08.10.tif.gz
# chirps-v2.0.1981.08.11.tif.gz
# chirps-v2.0.1981.08.12.tif.gz
# chirps-v2.0.1981.08.13.tif.gz
# chirps-v2.0.1981.08.14.tif.gz
# chirps-v2.0.1981.08.15.tif.gz
# chirps-v2.0.1981.08.16.tif.gz
# chirps-v2.0.1981.08.17.tif.gz
# chirps-v2.0.1981.08.18.tif.gz
# chirps-v2.0.1981.08.19.tif.gz
# chirps-v2.0.1981.08.20.tif.gz
# chirps-v2.0.1981.08.21.tif.gz
# chirps-v2.0.1981.08.22.tif.gz
# chirps-v2.0.1981.08.23.tif.gz
# chirps-v2.0.1981.08.24.tif.gz
# chirps-v2.0.1981.08.25.tif.gz
# chirps-v2.0.1981.08.26.tif.gz
# chirps-v2.0.1981.08.27.tif.gz
# chirps-v2.0.1981.08.28.tif.gz
# chirps-v2.0.1981.08.29.tif.gz
# chirps-v2.0.1981.08.30.tif.gz
# chirps-v2.0.1981.08.31.tif.gz
# chirps-v2.0.1981.09.01.tif.gz
# chirps-v2.0.1981.09.02.tif.gz
# chirps-v2.0.1981.09.03.tif.gz
# chirps-v2.0.1981.09.04.tif.gz
# chirps-v2.0.1981.09.05.tif.gz
# chirps-v2.0.1981.09.06.tif.gz
# chirps-v2.0.1981.09.07.tif.gz
# chirps-v2.0.1981.09.08.tif.gz
# chirps-v2.0.1981.09.09.tif.gz
# chirps-v2.0.1981.09.10.tif.gz
# chirps-v2.0.1981.09.11.tif.gz
# chirps-v2.0.1981.09.12.tif.gz
# chirps-v2.0.1981.09.13.tif.gz
# chirps-v2.0.1981.09.14.tif.gz
# chirps-v2.0.1981.09.15.tif.gz
# chirps-v2.0.1981.09.16.tif.gz
# chirps-v2.0.1981.09.17.tif.gz
# chirps-v2.0.1981.09.18.tif.gz
# chirps-v2.0.1981.09.19.tif.gz
# chirps-v2.0.1981.09.20.tif.gz
# chirps-v2.0.1981.09.21.tif.gz
# chirps-v2.0.1981.09.22.tif.gz
# chirps-v2.0.1981.09.23.tif.gz
# chirps-v2.0.1981.09.24.tif.gz
# chirps-v2.0.1981.09.25.tif.gz
# chirps-v2.0.1981.09.26.tif.gz
# chirps-v2.0.1981.09.27.tif.gz
# chirps-v2.0.1981.09.28.tif.gz
# chirps-v2.0.1981.09.29.tif.gz
# chirps-v2.0.1981.09.30.tif.gz
# NOk
# chirps-v2.0.1981.10.01.tif.gz
# chirps-v2.0.1981.10.02.tif.gz
# chirps-v2.0.1981.10.03.tif.gz
# chirps-v2.0.1981.10.04.tif.gz
# chirps-v2.0.1981.10.05.tif.gz
# chirps-v2.0.1981.10.06.tif.gz
# chirps-v2.0.1981.10.07.tif.gz
# chirps-v2.0.1981.10.08.tif.gz
# chirps-v2.0.1981.10.09.tif.gz
# chirps-v2.0.1981.10.10.tif.gz
# chirps-v2.0.1981.10.11.tif.gz
# chirps-v2.0.1981.10.12.tif.gz
# chirps-v2.0.1981.10.13.tif.gz
# chirps-v2.0.1981.10.14.tif.gz
# chirps-v2.0.1981.10.15.tif.gz
# chirps-v2.0.1981.10.16.tif.gz
# chirps-v2.0.1981.10.17.tif.gz
# chirps-v2.0.1981.10.18.tif.gz
# chirps-v2.0.1981.10.19.tif.gz
# chirps-v2.0.1981.10.20.tif.gz
# chirps-v2.0.1981.10.21.tif.gz
# chirps-v2.0.1981.10.22.tif.gz
# chirps-v2.0.1981.10.23.tif.gz
# chirps-v2.0.1981.10.24.tif.gz
# chirps-v2.0.1981.10.25.tif.gz
# chirps-v2.0.1981.10.26.tif.gz
# chirps-v2.0.1981.10.27.tif.gz
# chirps-v2.0.1981.10.28.tif.gz
# chirps-v2.0.1981.10.29.tif.gz
# chirps-v2.0.1981.10.30.tif.gz
# chirps-v2.0.1981.10.31.tif.gz
# chirps-v2.0.1981.11.01.tif.gz
# chirps-v2.0.1981.11.02.tif.gz
# chirps-v2.0.1981.11.03.tif.gz
# chirps-v2.0.1981.11.04.tif.gz
# chirps-v2.0.1981.11.05.tif.gz
# chirps-v2.0.1981.11.06.tif.gz
# chirps-v2.0.1981.11.07.tif.gz
# chirps-v2.0.1981.11.08.tif.gz
# chirps-v2.0.1981.11.09.tif.gz
# chirps-v2.0.1981.11.10.tif.gz
# chirps-v2.0.1981.11.11.tif.gz
# chirps-v2.0.1981.11.12.tif.gz
# chirps-v2.0.1981.11.13.tif.gz
# chirps-v2.0.1981.11.14.tif.gz
# chirps-v2.0.1981.11.15.tif.gz
# chirps-v2.0.1981.11.16.tif.gz
# chirps-v2.0.1981.11.17.tif.gz
# chirps-v2.0.1981.11.18.tif.gz
# chirps-v2.0.1981.11.19.tif.gz
# chirps-v2.0.1981.11.20.tif.gz
# chirps-v2.0.1981.11.21.tif.gz
# chirps-v2.0.1981.11.22.tif.gz
# chirps-v2.0.1981.11.23.tif.gz
# chirps-v2.0.1981.11.24.tif.gz
# chirps-v2.0.1981.11.25.tif.gz
# chirps-v2.0.1981.11.26.tif.gz
# chirps-v2.0.1981.11.27.tif.gz
# chirps-v2.0.1981.11.28.tif.gz
# chirps-v2.0.1981.11.29.tif.gz
# chirps-v2.0.1981.11.30.tif.gz
# NOk
# chirps-v2.0.1981.12.01.tif.gz
# chirps-v2.0.1981.12.02.tif.gz
# chirps-v2.0.1981.12.03.tif.gz
# chirps-v2.0.1981.12.04.tif.gz
# chirps-v2.0.1981.12.05.tif.gz
# chirps-v2.0.1981.12.06.tif.gz
# chirps-v2.0.1981.12.07.tif.gz
# chirps-v2.0.1981.12.08.tif.gz
# chirps-v2.0.1981.12.09.tif.gz
# chirps-v2.0.1981.12.10.tif.gz
# chirps-v2.0.1981.12.11.tif.gz
# chirps-v2.0.1981.12.12.tif.gz
# chirps-v2.0.1981.12.13.tif.gz
# chirps-v2.0.1981.12.14.tif.gz
# chirps-v2.0.1981.12.15.tif.gz
# chirps-v2.0.1981.12.16.tif.gz
# chirps-v2.0.1981.12.17.tif.gz
# chirps-v2.0.1981.12.18.tif.gz
# chirps-v2.0.1981.12.19.tif.gz
# chirps-v2.0.1981.12.20.tif.gz
# chirps-v2.0.1981.12.21.tif.gz
# chirps-v2.0.1981.12.22.tif.gz
# chirps-v2.0.1981.12.23.tif.gz
# chirps-v2.0.1981.12.24.tif.gz
# chirps-v2.0.1981.12.25.tif.gz
# chirps-v2.0.1981.12.26.tif.gz
# chirps-v2.0.1981.12.27.tif.gz
# chirps-v2.0.1981.12.28.tif.gz
# chirps-v2.0.1981.12.29.tif.gz
# chirps-v2.0.1981.12.30.tif.gz
# chirps-v2.0.1981.12.31.tif.gz
# chirps-v2.0.1982.01.01.tif.gz
# chirps-v2.0.1982.01.02.tif.gz
# chirps-v2.0.1982.01.03.tif.gz
# chirps-v2.0.1982.01.04.tif.gz
# chirps-v2.0.1982.01.05.tif.gz
# chirps-v2.0.1982.01.06.tif.gz
# chirps-v2.0.1982.01.07.tif.gz
# chirps-v2.0.1982.01.08.tif.gz
# chirps-v2.0.1982.01.09.tif.gz
# chirps-v2.0.1982.01.10.tif.gz
# chirps-v2.0.1982.01.11.tif.gz
# chirps-v2.0.1982.01.12.tif.gz
# chirps-v2.0.1982.01.13.tif.gz
# chirps-v2.0.1982.01.14.tif.gz
# chirps-v2.0.1982.01.15.tif.gz
# chirps-v2.0.1982.01.16.tif.gz
# chirps-v2.0.1982.01.17.tif.gz
# chirps-v2.0.1982.01.18.tif.gz
# chirps-v2.0.1982.01.19.tif.gz
# chirps-v2.0.1982.01.20.tif.gz
# chirps-v2.0.1982.01.21.tif.gz
# chirps-v2.0.1982.01.22.tif.gz
# chirps-v2.0.1982.01.23.tif.gz
# chirps-v2.0.1982.01.24.tif.gz
# chirps-v2.0.1982.01.25.tif.gz
# chirps-v2.0.1982.01.26.tif.gz
# chirps-v2.0.1982.01.27.tif.gz
# chirps-v2.0.1982.01.28.tif.gz
# chirps-v2.0.1982.01.29.tif.gz
# chirps-v2.0.1982.01.30.tif.gz
# chirps-v2.0.1982.01.31.tif.gz
# chirps-v2.0.1982.02.01.tif.gz
# chirps-v2.0.1982.02.02.tif.gz
# chirps-v2.0.1982.02.03.tif.gz
# chirps-v2.0.1982.02.04.tif.gz
# chirps-v2.0.1982.02.05.tif.gz
# chirps-v2.0.1982.02.06.tif.gz
# chirps-v2.0.1982.02.07.tif.gz
# chirps-v2.0.1982.02.08.tif.gz
# chirps-v2.0.1982.02.09.tif.gz
# chirps-v2.0.1982.02.10.tif.gz
# chirps-v2.0.1982.02.11.tif.gz
# chirps-v2.0.1982.02.12.tif.gz
# chirps-v2.0.1982.02.13.tif.gz
# chirps-v2.0.1982.02.14.tif.gz
# chirps-v2.0.1982.02.15.tif.gz
# chirps-v2.0.1982.02.16.tif.gz
# chirps-v2.0.1982.02.17.tif.gz
# chirps-v2.0.1982.02.18.tif.gz
# chirps-v2.0.1982.02.19.tif.gz
# chirps-v2.0.1982.02.20.tif.gz
# chirps-v2.0.1982.02.21.tif.gz
# chirps-v2.0.1982.02.22.tif.gz
# chirps-v2.0.1982.02.23.tif.gz
# chirps-v2.0.1982.02.24.tif.gz
# chirps-v2.0.1982.02.25.tif.gz
# chirps-v2.0.1982.02.26.tif.gz
# chirps-v2.0.1982.02.27.tif.gz
# chirps-v2.0.1982.02.28.tif.gz
# NOk
# NOk
# NOk
# chirps-v2.0.1982.03.01.tif.gz
# chirps-v2.0.1982.03.02.tif.gz
# chirps-v2.0.1982.03.03.tif.gz
# chirps-v2.0.1982.03.04.tif.gz
# chirps-v2.0.1982.03.05.tif.gz
# chirps-v2.0.1982.03.06.tif.gz
# chirps-v2.0.1982.03.07.tif.gz
# chirps-v2.0.1982.03.08.tif.gz
# chirps-v2.0.1982.03.09.tif.gz
# chirps-v2.0.1982.03.10.tif.gz
# chirps-v2.0.1982.03.11.tif.gz
# chirps-v2.0.1982.03.12.tif.gz
# chirps-v2.0.1982.03.13.tif.gz
# chirps-v2.0.1982.03.14.tif.gz
# chirps-v2.0.1982.03.15.tif.gz
# chirps-v2.0.1982.03.16.tif.gz
# chirps-v2.0.1982.03.17.tif.gz
# chirps-v2.0.1982.03.18.tif.gz
# chirps-v2.0.1982.03.19.tif.gz
# chirps-v2.0.1982.03.20.tif.gz
# chirps-v2.0.1982.03.21.tif.gz
# chirps-v2.0.1982.03.22.tif.gz
# chirps-v2.0.1982.03.23.tif.gz
# chirps-v2.0.1982.03.24.tif.gz
# chirps-v2.0.1982.03.25.tif.gz
# chirps-v2.0.1982.03.26.tif.gz
# chirps-v2.0.1982.03.27.tif.gz
# chirps-v2.0.1982.03.28.tif.gz
# chirps-v2.0.1982.03.29.tif.gz
# chirps-v2.0.1982.03.30.tif.gz
# chirps-v2.0.1982.03.31.tif.gz
# chirps-v2.0.1982.04.01.tif.gz
# chirps-v2.0.1982.04.02.tif.gz
# chirps-v2.0.1982.04.03.tif.gz
# chirps-v2.0.1982.04.04.tif.gz
# chirps-v2.0.1982.04.05.tif.gz
# chirps-v2.0.1982.04.06.tif.gz
# chirps-v2.0.1982.04.07.tif.gz
# chirps-v2.0.1982.04.08.tif.gz
# chirps-v2.0.1982.04.09.tif.gz
# chirps-v2.0.1982.04.10.tif.gz
# chirps-v2.0.1982.04.11.tif.gz
# chirps-v2.0.1982.04.12.tif.gz
# chirps-v2.0.1982.04.13.tif.gz
# chirps-v2.0.1982.04.14.tif.gz
# chirps-v2.0.1982.04.15.tif.gz
# chirps-v2.0.1982.04.16.tif.gz
# chirps-v2.0.1982.04.17.tif.gz
# chirps-v2.0.1982.04.18.tif.gz
# chirps-v2.0.1982.04.19.tif.gz
# chirps-v2.0.1982.04.20.tif.gz
# chirps-v2.0.1982.04.21.tif.gz
# chirps-v2.0.1982.04.22.tif.gz
# chirps-v2.0.1982.04.23.tif.gz
# chirps-v2.0.1982.04.24.tif.gz
# chirps-v2.0.1982.04.25.tif.gz
# chirps-v2.0.1982.04.26.tif.gz
# chirps-v2.0.1982.04.27.tif.gz
# chirps-v2.0.1982.04.28.tif.gz
# chirps-v2.0.1982.04.29.tif.gz
# chirps-v2.0.1982.04.30.tif.gz
# NOk
# chirps-v2.0.1982.05.01.tif.gz
# chirps-v2.0.1982.05.02.tif.gz
# chirps-v2.0.1982.05.03.tif.gz
# chirps-v2.0.1982.05.04.tif.gz
# chirps-v2.0.1982.05.05.tif.gz
# chirps-v2.0.1982.05.06.tif.gz
# chirps-v2.0.1982.05.07.tif.gz
# chirps-v2.0.1982.05.08.tif.gz
# chirps-v2.0.1982.05.09.tif.gz
# chirps-v2.0.1982.05.10.tif.gz
# chirps-v2.0.1982.05.11.tif.gz
# chirps-v2.0.1982.05.12.tif.gz
# chirps-v2.0.1982.05.13.tif.gz
# chirps-v2.0.1982.05.14.tif.gz
# chirps-v2.0.1982.05.15.tif.gz
# chirps-v2.0.1982.05.16.tif.gz
# chirps-v2.0.1982.05.17.tif.gz
# chirps-v2.0.1982.05.18.tif.gz
# chirps-v2.0.1982.05.19.tif.gz
# chirps-v2.0.1982.05.20.tif.gz
# chirps-v2.0.1982.05.21.tif.gz
# chirps-v2.0.1982.05.22.tif.gz
# chirps-v2.0.1982.05.23.tif.gz
# chirps-v2.0.1982.05.24.tif.gz
# chirps-v2.0.1982.05.25.tif.gz
# chirps-v2.0.1982.05.26.tif.gz
# chirps-v2.0.1982.05.27.tif.gz
# chirps-v2.0.1982.05.28.tif.gz
# chirps-v2.0.1982.05.29.tif.gz
# chirps-v2.0.1982.05.30.tif.gz
# chirps-v2.0.1982.05.31.tif.gz
# chirps-v2.0.1982.06.01.tif.gz
# chirps-v2.0.1982.06.02.tif.gz
# chirps-v2.0.1982.06.03.tif.gz
# chirps-v2.0.1982.06.04.tif.gz
# chirps-v2.0.1982.06.05.tif.gz
# chirps-v2.0.1982.06.06.tif.gz
# chirps-v2.0.1982.06.07.tif.gz
# chirps-v2.0.1982.06.08.tif.gz
# chirps-v2.0.1982.06.09.tif.gz
# chirps-v2.0.1982.06.10.tif.gz
# chirps-v2.0.1982.06.11.tif.gz
# chirps-v2.0.1982.06.12.tif.gz
# chirps-v2.0.1982.06.13.tif.gz
# chirps-v2.0.1982.06.14.tif.gz
# chirps-v2.0.1982.06.15.tif.gz
# chirps-v2.0.1982.06.16.tif.gz
# chirps-v2.0.1982.06.17.tif.gz
# chirps-v2.0.1982.06.18.tif.gz
# chirps-v2.0.1982.06.19.tif.gz
# chirps-v2.0.1982.06.20.tif.gz
# chirps-v2.0.1982.06.21.tif.gz
# chirps-v2.0.1982.06.22.tif.gz
# chirps-v2.0.1982.06.23.tif.gz
# chirps-v2.0.1982.06.24.tif.gz
# chirps-v2.0.1982.06.25.tif.gz
# chirps-v2.0.1982.06.26.tif.gz
# chirps-v2.0.1982.06.27.tif.gz
# chirps-v2.0.1982.06.28.tif.gz
# chirps-v2.0.1982.06.29.tif.gz
# chirps-v2.0.1982.06.30.tif.gz
# NOk
# chirps-v2.0.1982.07.01.tif.gz
# chirps-v2.0.1982.07.02.tif.gz
# chirps-v2.0.1982.07.03.tif.gz
# chirps-v2.0.1982.07.04.tif.gz
# chirps-v2.0.1982.07.05.tif.gz
# chirps-v2.0.1982.07.06.tif.gz
# chirps-v2.0.1982.07.07.tif.gz
# chirps-v2.0.1982.07.08.tif.gz
# chirps-v2.0.1982.07.09.tif.gz
# chirps-v2.0.1982.07.10.tif.gz
# chirps-v2.0.1982.07.11.tif.gz
# chirps-v2.0.1982.07.12.tif.gz
# chirps-v2.0.1982.07.13.tif.gz
# chirps-v2.0.1982.07.14.tif.gz
# chirps-v2.0.1982.07.15.tif.gz
# chirps-v2.0.1982.07.16.tif.gz
# chirps-v2.0.1982.07.17.tif.gz
# chirps-v2.0.1982.07.18.tif.gz
# chirps-v2.0.1982.07.19.tif.gz
# chirps-v2.0.1982.07.20.tif.gz
# chirps-v2.0.1982.07.21.tif.gz
# chirps-v2.0.1982.07.22.tif.gz
# chirps-v2.0.1982.07.23.tif.gz
# chirps-v2.0.1982.07.24.tif.gz
# chirps-v2.0.1982.07.25.tif.gz
# chirps-v2.0.1982.07.26.tif.gz
# chirps-v2.0.1982.07.27.tif.gz
# chirps-v2.0.1982.07.28.tif.gz
# chirps-v2.0.1982.07.29.tif.gz
# chirps-v2.0.1982.07.30.tif.gz
# chirps-v2.0.1982.07.31.tif.gz
# chirps-v2.0.1982.08.01.tif.gz
# chirps-v2.0.1982.08.02.tif.gz
# chirps-v2.0.1982.08.03.tif.gz
# chirps-v2.0.1982.08.04.tif.gz
# chirps-v2.0.1982.08.05.tif.gz
# chirps-v2.0.1982.08.06.tif.gz
# chirps-v2.0.1982.08.07.tif.gz
# chirps-v2.0.1982.08.08.tif.gz
# chirps-v2.0.1982.08.09.tif.gz
# chirps-v2.0.1982.08.10.tif.gz
# chirps-v2.0.1982.08.11.tif.gz
# chirps-v2.0.1982.08.12.tif.gz
# chirps-v2.0.1982.08.13.tif.gz
# chirps-v2.0.1982.08.14.tif.gz
# chirps-v2.0.1982.08.15.tif.gz
# chirps-v2.0.1982.08.16.tif.gz
# chirps-v2.0.1982.08.17.tif.gz
# chirps-v2.0.1982.08.18.tif.gz
# chirps-v2.0.1982.08.19.tif.gz
# chirps-v2.0.1982.08.20.tif.gz
# chirps-v2.0.1982.08.21.tif.gz
# chirps-v2.0.1982.08.22.tif.gz
# chirps-v2.0.1982.08.23.tif.gz
# chirps-v2.0.1982.08.24.tif.gz
# chirps-v2.0.1982.08.25.tif.gz
# chirps-v2.0.1982.08.26.tif.gz
# chirps-v2.0.1982.08.27.tif.gz
# chirps-v2.0.1982.08.28.tif.gz
# chirps-v2.0.1982.08.29.tif.gz
# chirps-v2.0.1982.08.30.tif.gz
# chirps-v2.0.1982.08.31.tif.gz
# chirps-v2.0.1982.09.01.tif.gz
# chirps-v2.0.1982.09.02.tif.gz
# chirps-v2.0.1982.09.03.tif.gz
# chirps-v2.0.1982.09.04.tif.gz
# chirps-v2.0.1982.09.05.tif.gz
# chirps-v2.0.1982.09.06.tif.gz
# chirps-v2.0.1982.09.07.tif.gz
# chirps-v2.0.1982.09.08.tif.gz
# chirps-v2.0.1982.09.09.tif.gz
# chirps-v2.0.1982.09.10.tif.gz
# chirps-v2.0.1982.09.11.tif.gz
# chirps-v2.0.1982.09.12.tif.gz
# chirps-v2.0.1982.09.13.tif.gz
# chirps-v2.0.1982.09.14.tif.gz
# chirps-v2.0.1982.09.15.tif.gz
# chirps-v2.0.1982.09.16.tif.gz
# chirps-v2.0.1982.09.17.tif.gz
# chirps-v2.0.1982.09.18.tif.gz
# chirps-v2.0.1982.09.19.tif.gz
# chirps-v2.0.1982.09.20.tif.gz
# chirps-v2.0.1982.09.21.tif.gz
# chirps-v2.0.1982.09.22.tif.gz
# chirps-v2.0.1982.09.23.tif.gz
# chirps-v2.0.1982.09.24.tif.gz
# chirps-v2.0.1982.09.25.tif.gz
# chirps-v2.0.1982.09.26.tif.gz
# chirps-v2.0.1982.09.27.tif.gz
# chirps-v2.0.1982.09.28.tif.gz
# chirps-v2.0.1982.09.29.tif.gz
# chirps-v2.0.1982.09.30.tif.gz
# NOk
# chirps-v2.0.1982.10.01.tif.gz
# chirps-v2.0.1982.10.02.tif.gz
# chirps-v2.0.1982.10.03.tif.gz
# chirps-v2.0.1982.10.04.tif.gz
# chirps-v2.0.1982.10.05.tif.gz
# chirps-v2.0.1982.10.06.tif.gz
# chirps-v2.0.1982.10.07.tif.gz
# chirps-v2.0.1982.10.08.tif.gz
# chirps-v2.0.1982.10.09.tif.gz
# chirps-v2.0.1982.10.10.tif.gz
# chirps-v2.0.1982.10.11.tif.gz
# chirps-v2.0.1982.10.12.tif.gz
# chirps-v2.0.1982.10.13.tif.gz
# chirps-v2.0.1982.10.14.tif.gz
# chirps-v2.0.1982.10.15.tif.gz
# chirps-v2.0.1982.10.16.tif.gz
# chirps-v2.0.1982.10.17.tif.gz
# chirps-v2.0.1982.10.18.tif.gz
# chirps-v2.0.1982.10.19.tif.gz
# chirps-v2.0.1982.10.20.tif.gz
# chirps-v2.0.1982.10.21.tif.gz
# chirps-v2.0.1982.10.22.tif.gz
# chirps-v2.0.1982.10.23.tif.gz
# chirps-v2.0.1982.10.24.tif.gz
# chirps-v2.0.1982.10.25.tif.gz
# chirps-v2.0.1982.10.26.tif.gz
# chirps-v2.0.1982.10.27.tif.gz
# chirps-v2.0.1982.10.28.tif.gz
# chirps-v2.0.1982.10.29.tif.gz
# chirps-v2.0.1982.10.30.tif.gz
# chirps-v2.0.1982.10.31.tif.gz
# chirps-v2.0.1982.11.01.tif.gz
# chirps-v2.0.1982.11.02.tif.gz
# chirps-v2.0.1982.11.03.tif.gz
# chirps-v2.0.1982.11.04.tif.gz
# chirps-v2.0.1982.11.05.tif.gz
# chirps-v2.0.1982.11.06.tif.gz
# chirps-v2.0.1982.11.07.tif.gz
# chirps-v2.0.1982.11.08.tif.gz
# chirps-v2.0.1982.11.09.tif.gz
# chirps-v2.0.1982.11.10.tif.gz
# chirps-v2.0.1982.11.11.tif.gz
# chirps-v2.0.1982.11.12.tif.gz
# chirps-v2.0.1982.11.13.tif.gz
# chirps-v2.0.1982.11.14.tif.gz
# chirps-v2.0.1982.11.15.tif.gz
# chirps-v2.0.1982.11.16.tif.gz
# chirps-v2.0.1982.11.17.tif.gz
# chirps-v2.0.1982.11.18.tif.gz
# chirps-v2.0.1982.11.19.tif.gz
# chirps-v2.0.1982.11.20.tif.gz
# chirps-v2.0.1982.11.21.tif.gz
# chirps-v2.0.1982.11.22.tif.gz
# chirps-v2.0.1982.11.23.tif.gz
# chirps-v2.0.1982.11.24.tif.gz
# chirps-v2.0.1982.11.25.tif.gz
# chirps-v2.0.1982.11.26.tif.gz
# chirps-v2.0.1982.11.27.tif.gz
# chirps-v2.0.1982.11.28.tif.gz
# chirps-v2.0.1982.11.29.tif.gz
# chirps-v2.0.1982.11.30.tif.gz
# NOk
# chirps-v2.0.1982.12.01.tif.gz
# chirps-v2.0.1982.12.02.tif.gz
# chirps-v2.0.1982.12.03.tif.gz
# chirps-v2.0.1982.12.04.tif.gz
# chirps-v2.0.1982.12.05.tif.gz
# chirps-v2.0.1982.12.06.tif.gz
# chirps-v2.0.1982.12.07.tif.gz
# chirps-v2.0.1982.12.08.tif.gz
# chirps-v2.0.1982.12.09.tif.gz
# chirps-v2.0.1982.12.10.tif.gz
# chirps-v2.0.1982.12.11.tif.gz
# chirps-v2.0.1982.12.12.tif.gz
# chirps-v2.0.1982.12.13.tif.gz
# chirps-v2.0.1982.12.14.tif.gz
# chirps-v2.0.1982.12.15.tif.gz
# chirps-v2.0.1982.12.16.tif.gz
# chirps-v2.0.1982.12.17.tif.gz
# chirps-v2.0.1982.12.18.tif.gz
# chirps-v2.0.1982.12.19.tif.gz
# chirps-v2.0.1982.12.20.tif.gz
# chirps-v2.0.1982.12.21.tif.gz
# chirps-v2.0.1982.12.22.tif.gz
# chirps-v2.0.1982.12.23.tif.gz
# chirps-v2.0.1982.12.24.tif.gz
# chirps-v2.0.1982.12.25.tif.gz
# chirps-v2.0.1982.12.26.tif.gz
# chirps-v2.0.1982.12.27.tif.gz
# chirps-v2.0.1982.12.28.tif.gz
# chirps-v2.0.1982.12.29.tif.gz
# chirps-v2.0.1982.12.30.tif.gz
# chirps-v2.0.1982.12.31.tif.gz
# chirps-v2.0.1983.01.01.tif.gz
# chirps-v2.0.1983.01.02.tif.gz
# chirps-v2.0.1983.01.03.tif.gz
# chirps-v2.0.1983.01.04.tif.gz
# chirps-v2.0.1983.01.05.tif.gz
# chirps-v2.0.1983.01.06.tif.gz
# chirps-v2.0.1983.01.07.tif.gz
# chirps-v2.0.1983.01.08.tif.gz
# chirps-v2.0.1983.01.09.tif.gz
# chirps-v2.0.1983.01.10.tif.gz
# chirps-v2.0.1983.01.11.tif.gz
# chirps-v2.0.1983.01.12.tif.gz
# chirps-v2.0.1983.01.13.tif.gz
# chirps-v2.0.1983.01.14.tif.gz
# chirps-v2.0.1983.01.15.tif.gz
# chirps-v2.0.1983.01.16.tif.gz
# chirps-v2.0.1983.01.17.tif.gz
# chirps-v2.0.1983.01.18.tif.gz
# chirps-v2.0.1983.01.19.tif.gz
# chirps-v2.0.1983.01.20.tif.gz
# chirps-v2.0.1983.01.21.tif.gz
# chirps-v2.0.1983.01.22.tif.gz
# chirps-v2.0.1983.01.23.tif.gz
# chirps-v2.0.1983.01.24.tif.gz
# chirps-v2.0.1983.01.25.tif.gz
# chirps-v2.0.1983.01.26.tif.gz
# chirps-v2.0.1983.01.27.tif.gz
# chirps-v2.0.1983.01.28.tif.gz
# chirps-v2.0.1983.01.29.tif.gz
# chirps-v2.0.1983.01.30.tif.gz
# chirps-v2.0.1983.01.31.tif.gz
# chirps-v2.0.1983.02.01.tif.gz
# chirps-v2.0.1983.02.02.tif.gz
# chirps-v2.0.1983.02.03.tif.gz
# chirps-v2.0.1983.02.04.tif.gz
# chirps-v2.0.1983.02.05.tif.gz
# chirps-v2.0.1983.02.06.tif.gz
# chirps-v2.0.1983.02.07.tif.gz
# chirps-v2.0.1983.02.08.tif.gz
# chirps-v2.0.1983.02.09.tif.gz
# chirps-v2.0.1983.02.10.tif.gz
# chirps-v2.0.1983.02.11.tif.gz
# chirps-v2.0.1983.02.12.tif.gz
# chirps-v2.0.1983.02.13.tif.gz
# chirps-v2.0.1983.02.14.tif.gz
# chirps-v2.0.1983.02.15.tif.gz
# chirps-v2.0.1983.02.16.tif.gz
# chirps-v2.0.1983.02.17.tif.gz
# chirps-v2.0.1983.02.18.tif.gz
# chirps-v2.0.1983.02.19.tif.gz
# chirps-v2.0.1983.02.20.tif.gz
# chirps-v2.0.1983.02.21.tif.gz
# chirps-v2.0.1983.02.22.tif.gz
# chirps-v2.0.1983.02.23.tif.gz
# chirps-v2.0.1983.02.24.tif.gz
# chirps-v2.0.1983.02.25.tif.gz
# chirps-v2.0.1983.02.26.tif.gz
# chirps-v2.0.1983.02.27.tif.gz
# chirps-v2.0.1983.02.28.tif.gz
# NOk
# NOk
# NOk
# chirps-v2.0.1983.03.01.tif.gz
# chirps-v2.0.1983.03.02.tif.gz
# chirps-v2.0.1983.03.03.tif.gz
# chirps-v2.0.1983.03.04.tif.gz
# chirps-v2.0.1983.03.05.tif.gz
# chirps-v2.0.1983.03.06.tif.gz
# chirps-v2.0.1983.03.07.tif.gz
# chirps-v2.0.1983.03.08.tif.gz
# chirps-v2.0.1983.03.09.tif.gz
# chirps-v2.0.1983.03.10.tif.gz
# chirps-v2.0.1983.03.11.tif.gz
# chirps-v2.0.1983.03.12.tif.gz
# chirps-v2.0.1983.03.13.tif.gz
# chirps-v2.0.1983.03.14.tif.gz
# chirps-v2.0.1983.03.15.tif.gz
# chirps-v2.0.1983.03.16.tif.gz
# chirps-v2.0.1983.03.17.tif.gz
# chirps-v2.0.1983.03.18.tif.gz
# chirps-v2.0.1983.03.19.tif.gz
# chirps-v2.0.1983.03.20.tif.gz
# chirps-v2.0.1983.03.21.tif.gz
# chirps-v2.0.1983.03.22.tif.gz
# chirps-v2.0.1983.03.23.tif.gz
# chirps-v2.0.1983.03.24.tif.gz
# chirps-v2.0.1983.03.25.tif.gz
# chirps-v2.0.1983.03.26.tif.gz
# chirps-v2.0.1983.03.27.tif.gz
# chirps-v2.0.1983.03.28.tif.gz
# chirps-v2.0.1983.03.29.tif.gz
# chirps-v2.0.1983.03.30.tif.gz
# chirps-v2.0.1983.03.31.tif.gz
# chirps-v2.0.1983.04.01.tif.gz
# chirps-v2.0.1983.04.02.tif.gz
# chirps-v2.0.1983.04.03.tif.gz
# chirps-v2.0.1983.04.04.tif.gz
# chirps-v2.0.1983.04.05.tif.gz
# chirps-v2.0.1983.04.06.tif.gz
# chirps-v2.0.1983.04.07.tif.gz
# chirps-v2.0.1983.04.08.tif.gz
# chirps-v2.0.1983.04.09.tif.gz
# chirps-v2.0.1983.04.10.tif.gz
# chirps-v2.0.1983.04.11.tif.gz
# chirps-v2.0.1983.04.12.tif.gz
# chirps-v2.0.1983.04.13.tif.gz
# chirps-v2.0.1983.04.14.tif.gz
# chirps-v2.0.1983.04.15.tif.gz
# chirps-v2.0.1983.04.16.tif.gz
# chirps-v2.0.1983.04.17.tif.gz
# chirps-v2.0.1983.04.18.tif.gz
# chirps-v2.0.1983.04.19.tif.gz
# chirps-v2.0.1983.04.20.tif.gz
# chirps-v2.0.1983.04.21.tif.gz
# chirps-v2.0.1983.04.22.tif.gz
# chirps-v2.0.1983.04.23.tif.gz
# chirps-v2.0.1983.04.24.tif.gz
# chirps-v2.0.1983.04.25.tif.gz
# chirps-v2.0.1983.04.26.tif.gz
# chirps-v2.0.1983.04.27.tif.gz
# chirps-v2.0.1983.04.28.tif.gz
# chirps-v2.0.1983.04.29.tif.gz
# chirps-v2.0.1983.04.30.tif.gz
# NOk
# chirps-v2.0.1983.05.01.tif.gz
# chirps-v2.0.1983.05.02.tif.gz
# chirps-v2.0.1983.05.03.tif.gz
# chirps-v2.0.1983.05.04.tif.gz
# chirps-v2.0.1983.05.05.tif.gz
# chirps-v2.0.1983.05.06.tif.gz
# chirps-v2.0.1983.05.07.tif.gz
# chirps-v2.0.1983.05.08.tif.gz
# chirps-v2.0.1983.05.09.tif.gz
# chirps-v2.0.1983.05.10.tif.gz
# chirps-v2.0.1983.05.11.tif.gz
# chirps-v2.0.1983.05.12.tif.gz
# chirps-v2.0.1983.05.13.tif.gz
# chirps-v2.0.1983.05.14.tif.gz
# chirps-v2.0.1983.05.15.tif.gz
# chirps-v2.0.1983.05.16.tif.gz
# chirps-v2.0.1983.05.17.tif.gz
# chirps-v2.0.1983.05.18.tif.gz
# chirps-v2.0.1983.05.19.tif.gz
# chirps-v2.0.1983.05.20.tif.gz
# chirps-v2.0.1983.05.21.tif.gz
# chirps-v2.0.1983.05.22.tif.gz
# chirps-v2.0.1983.05.23.tif.gz
# chirps-v2.0.1983.05.24.tif.gz
# chirps-v2.0.1983.05.25.tif.gz
# chirps-v2.0.1983.05.26.tif.gz
# chirps-v2.0.1983.05.27.tif.gz
# chirps-v2.0.1983.05.28.tif.gz
# chirps-v2.0.1983.05.29.tif.gz
# chirps-v2.0.1983.05.30.tif.gz
# chirps-v2.0.1983.05.31.tif.gz
# chirps-v2.0.1983.06.01.tif.gz
# chirps-v2.0.1983.06.02.tif.gz
# chirps-v2.0.1983.06.03.tif.gz
# chirps-v2.0.1983.06.04.tif.gz
# chirps-v2.0.1983.06.05.tif.gz
# chirps-v2.0.1983.06.06.tif.gz
# chirps-v2.0.1983.06.07.tif.gz
# chirps-v2.0.1983.06.08.tif.gz
# chirps-v2.0.1983.06.09.tif.gz
# chirps-v2.0.1983.06.10.tif.gz
# chirps-v2.0.1983.06.11.tif.gz
# chirps-v2.0.1983.06.12.tif.gz
# chirps-v2.0.1983.06.13.tif.gz
# chirps-v2.0.1983.06.14.tif.gz
# chirps-v2.0.1983.06.15.tif.gz
# chirps-v2.0.1983.06.16.tif.gz
# chirps-v2.0.1983.06.17.tif.gz
# chirps-v2.0.1983.06.18.tif.gz
# chirps-v2.0.1983.06.19.tif.gz
# chirps-v2.0.1983.06.20.tif.gz
# chirps-v2.0.1983.06.21.tif.gz
# chirps-v2.0.1983.06.22.tif.gz
# chirps-v2.0.1983.06.23.tif.gz
# chirps-v2.0.1983.06.24.tif.gz
# chirps-v2.0.1983.06.25.tif.gz
# chirps-v2.0.1983.06.26.tif.gz
# chirps-v2.0.1983.06.27.tif.gz
# chirps-v2.0.1983.06.28.tif.gz
# chirps-v2.0.1983.06.29.tif.gz
# chirps-v2.0.1983.06.30.tif.gz
# NOk
# chirps-v2.0.1983.07.01.tif.gz
# chirps-v2.0.1983.07.02.tif.gz
# chirps-v2.0.1983.07.03.tif.gz
# chirps-v2.0.1983.07.04.tif.gz
# chirps-v2.0.1983.07.05.tif.gz
# chirps-v2.0.1983.07.06.tif.gz
# chirps-v2.0.1983.07.07.tif.gz
# chirps-v2.0.1983.07.08.tif.gz
# chirps-v2.0.1983.07.09.tif.gz
# chirps-v2.0.1983.07.10.tif.gz
# chirps-v2.0.1983.07.11.tif.gz
# chirps-v2.0.1983.07.12.tif.gz
# chirps-v2.0.1983.07.13.tif.gz
# chirps-v2.0.1983.07.14.tif.gz
# chirps-v2.0.1983.07.15.tif.gz
# chirps-v2.0.1983.07.16.tif.gz
# chirps-v2.0.1983.07.17.tif.gz
# chirps-v2.0.1983.07.18.tif.gz
# chirps-v2.0.1983.07.19.tif.gz
# chirps-v2.0.1983.07.20.tif.gz
# chirps-v2.0.1983.07.21.tif.gz
# chirps-v2.0.1983.07.22.tif.gz
# chirps-v2.0.1983.07.23.tif.gz
# chirps-v2.0.1983.07.24.tif.gz
# chirps-v2.0.1983.07.25.tif.gz
# chirps-v2.0.1983.07.26.tif.gz
# chirps-v2.0.1983.07.27.tif.gz
# chirps-v2.0.1983.07.28.tif.gz
# chirps-v2.0.1983.07.29.tif.gz
# chirps-v2.0.1983.07.30.tif.gz
# chirps-v2.0.1983.07.31.tif.gz
# chirps-v2.0.1983.08.01.tif.gz
# chirps-v2.0.1983.08.02.tif.gz
# chirps-v2.0.1983.08.03.tif.gz
# chirps-v2.0.1983.08.04.tif.gz
# chirps-v2.0.1983.08.05.tif.gz
# chirps-v2.0.1983.08.06.tif.gz
# chirps-v2.0.1983.08.07.tif.gz
# chirps-v2.0.1983.08.08.tif.gz
# chirps-v2.0.1983.08.09.tif.gz
# chirps-v2.0.1983.08.10.tif.gz
# chirps-v2.0.1983.08.11.tif.gz
# chirps-v2.0.1983.08.12.tif.gz
# chirps-v2.0.1983.08.13.tif.gz
# chirps-v2.0.1983.08.14.tif.gz
# chirps-v2.0.1983.08.15.tif.gz
# chirps-v2.0.1983.08.16.tif.gz
# chirps-v2.0.1983.08.17.tif.gz
# chirps-v2.0.1983.08.18.tif.gz
# chirps-v2.0.1983.08.19.tif.gz
# chirps-v2.0.1983.08.20.tif.gz
# chirps-v2.0.1983.08.21.tif.gz
# chirps-v2.0.1983.08.22.tif.gz
# chirps-v2.0.1983.08.23.tif.gz
# chirps-v2.0.1983.08.24.tif.gz
# chirps-v2.0.1983.08.25.tif.gz
# chirps-v2.0.1983.08.26.tif.gz
# chirps-v2.0.1983.08.27.tif.gz
# chirps-v2.0.1983.08.28.tif.gz
# chirps-v2.0.1983.08.29.tif.gz
# chirps-v2.0.1983.08.30.tif.gz
# chirps-v2.0.1983.08.31.tif.gz
# chirps-v2.0.1983.09.01.tif.gz
# chirps-v2.0.1983.09.02.tif.gz
# chirps-v2.0.1983.09.03.tif.gz
# chirps-v2.0.1983.09.04.tif.gz
# chirps-v2.0.1983.09.05.tif.gz
# chirps-v2.0.1983.09.06.tif.gz
# chirps-v2.0.1983.09.07.tif.gz
# chirps-v2.0.1983.09.08.tif.gz
# chirps-v2.0.1983.09.09.tif.gz
# chirps-v2.0.1983.09.10.tif.gz
# chirps-v2.0.1983.09.11.tif.gz
# chirps-v2.0.1983.09.12.tif.gz
# chirps-v2.0.1983.09.13.tif.gz
# chirps-v2.0.1983.09.14.tif.gz
# chirps-v2.0.1983.09.15.tif.gz
# chirps-v2.0.1983.09.16.tif.gz
# chirps-v2.0.1983.09.17.tif.gz
# chirps-v2.0.1983.09.18.tif.gz
# chirps-v2.0.1983.09.19.tif.gz
# chirps-v2.0.1983.09.20.tif.gz
# chirps-v2.0.1983.09.21.tif.gz
# chirps-v2.0.1983.09.22.tif.gz
# chirps-v2.0.1983.09.23.tif.gz
# chirps-v2.0.1983.09.24.tif.gz
# chirps-v2.0.1983.09.25.tif.gz
# chirps-v2.0.1983.09.26.tif.gz
# chirps-v2.0.1983.09.27.tif.gz
# chirps-v2.0.1983.09.28.tif.gz
# chirps-v2.0.1983.09.29.tif.gz
# chirps-v2.0.1983.09.30.tif.gz
# NOk
# chirps-v2.0.1983.10.01.tif.gz
# chirps-v2.0.1983.10.02.tif.gz
# chirps-v2.0.1983.10.03.tif.gz
# chirps-v2.0.1983.10.04.tif.gz
# chirps-v2.0.1983.10.05.tif.gz
# chirps-v2.0.1983.10.06.tif.gz
# chirps-v2.0.1983.10.07.tif.gz
# chirps-v2.0.1983.10.08.tif.gz
# chirps-v2.0.1983.10.09.tif.gz
# chirps-v2.0.1983.10.10.tif.gz
# chirps-v2.0.1983.10.11.tif.gz
# chirps-v2.0.1983.10.12.tif.gz
# chirps-v2.0.1983.10.13.tif.gz
# chirps-v2.0.1983.10.14.tif.gz
# chirps-v2.0.1983.10.15.tif.gz
# chirps-v2.0.1983.10.16.tif.gz
# chirps-v2.0.1983.10.17.tif.gz
# chirps-v2.0.1983.10.18.tif.gz
# chirps-v2.0.1983.10.19.tif.gz
# chirps-v2.0.1983.10.20.tif.gz
# chirps-v2.0.1983.10.21.tif.gz
# chirps-v2.0.1983.10.22.tif.gz
# chirps-v2.0.1983.10.23.tif.gz
# chirps-v2.0.1983.10.24.tif.gz
# chirps-v2.0.1983.10.25.tif.gz
# chirps-v2.0.1983.10.26.tif.gz
# chirps-v2.0.1983.10.27.tif.gz
# chirps-v2.0.1983.10.28.tif.gz
# chirps-v2.0.1983.10.29.tif.gz
# chirps-v2.0.1983.10.30.tif.gz
# chirps-v2.0.1983.10.31.tif.gz
# chirps-v2.0.1983.11.01.tif.gz
# chirps-v2.0.1983.11.02.tif.gz
# chirps-v2.0.1983.11.03.tif.gz
# chirps-v2.0.1983.11.04.tif.gz
# chirps-v2.0.1983.11.05.tif.gz
# chirps-v2.0.1983.11.06.tif.gz
# chirps-v2.0.1983.11.07.tif.gz
# chirps-v2.0.1983.11.08.tif.gz
# chirps-v2.0.1983.11.09.tif.gz
# chirps-v2.0.1983.11.10.tif.gz
# chirps-v2.0.1983.11.11.tif.gz
# chirps-v2.0.1983.11.12.tif.gz
# chirps-v2.0.1983.11.13.tif.gz
# chirps-v2.0.1983.11.14.tif.gz
# chirps-v2.0.1983.11.15.tif.gz
# chirps-v2.0.1983.11.16.tif.gz
# chirps-v2.0.1983.11.17.tif.gz
# chirps-v2.0.1983.11.18.tif.gz
# chirps-v2.0.1983.11.19.tif.gz
# chirps-v2.0.1983.11.20.tif.gz
# chirps-v2.0.1983.11.21.tif.gz
# chirps-v2.0.1983.11.22.tif.gz
# chirps-v2.0.1983.11.23.tif.gz
# chirps-v2.0.1983.11.24.tif.gz
# chirps-v2.0.1983.11.25.tif.gz
# chirps-v2.0.1983.11.26.tif.gz
# chirps-v2.0.1983.11.27.tif.gz
# chirps-v2.0.1983.11.28.tif.gz
# chirps-v2.0.1983.11.29.tif.gz
# chirps-v2.0.1983.11.30.tif.gz
# NOk
# chirps-v2.0.1983.12.01.tif.gz
# chirps-v2.0.1983.12.02.tif.gz
# chirps-v2.0.1983.12.03.tif.gz
# chirps-v2.0.1983.12.04.tif.gz
# chirps-v2.0.1983.12.05.tif.gz
# chirps-v2.0.1983.12.06.tif.gz
# chirps-v2.0.1983.12.07.tif.gz
# chirps-v2.0.1983.12.08.tif.gz
# chirps-v2.0.1983.12.09.tif.gz
# chirps-v2.0.1983.12.10.tif.gz
# chirps-v2.0.1983.12.11.tif.gz
# chirps-v2.0.1983.12.12.tif.gz
# chirps-v2.0.1983.12.13.tif.gz
# chirps-v2.0.1983.12.14.tif.gz
# chirps-v2.0.1983.12.15.tif.gz
# chirps-v2.0.1983.12.16.tif.gz
# chirps-v2.0.1983.12.17.tif.gz
# chirps-v2.0.1983.12.18.tif.gz
# chirps-v2.0.1983.12.19.tif.gz
# chirps-v2.0.1983.12.20.tif.gz
# chirps-v2.0.1983.12.21.tif.gz
# chirps-v2.0.1983.12.22.tif.gz
# chirps-v2.0.1983.12.23.tif.gz
# chirps-v2.0.1983.12.24.tif.gz
# chirps-v2.0.1983.12.25.tif.gz
# chirps-v2.0.1983.12.26.tif.gz
# chirps-v2.0.1983.12.27.tif.gz
# chirps-v2.0.1983.12.28.tif.gz
# chirps-v2.0.1983.12.29.tif.gz
# chirps-v2.0.1983.12.30.tif.gz
# chirps-v2.0.1983.12.31.tif.gz
# chirps-v2.0.1984.01.01.tif.gz
# chirps-v2.0.1984.01.02.tif.gz
# chirps-v2.0.1984.01.03.tif.gz
# chirps-v2.0.1984.01.04.tif.gz
# chirps-v2.0.1984.01.05.tif.gz
# chirps-v2.0.1984.01.06.tif.gz
# chirps-v2.0.1984.01.07.tif.gz
# chirps-v2.0.1984.01.08.tif.gz
# chirps-v2.0.1984.01.09.tif.gz
# chirps-v2.0.1984.01.10.tif.gz
# chirps-v2.0.1984.01.11.tif.gz
# chirps-v2.0.1984.01.12.tif.gz
# chirps-v2.0.1984.01.13.tif.gz
# chirps-v2.0.1984.01.14.tif.gz
# chirps-v2.0.1984.01.15.tif.gz
# chirps-v2.0.1984.01.16.tif.gz
# chirps-v2.0.1984.01.17.tif.gz
# chirps-v2.0.1984.01.18.tif.gz
# chirps-v2.0.1984.01.19.tif.gz
# chirps-v2.0.1984.01.20.tif.gz
# chirps-v2.0.1984.01.21.tif.gz
# chirps-v2.0.1984.01.22.tif.gz
# chirps-v2.0.1984.01.23.tif.gz
# chirps-v2.0.1984.01.24.tif.gz
# chirps-v2.0.1984.01.25.tif.gz
# chirps-v2.0.1984.01.26.tif.gz
# chirps-v2.0.1984.01.27.tif.gz
# chirps-v2.0.1984.01.28.tif.gz
# chirps-v2.0.1984.01.29.tif.gz
# chirps-v2.0.1984.01.30.tif.gz
# chirps-v2.0.1984.01.31.tif.gz
# chirps-v2.0.1984.02.01.tif.gz
# chirps-v2.0.1984.02.02.tif.gz
# chirps-v2.0.1984.02.03.tif.gz
# chirps-v2.0.1984.02.04.tif.gz
# chirps-v2.0.1984.02.05.tif.gz
# chirps-v2.0.1984.02.06.tif.gz
# chirps-v2.0.1984.02.07.tif.gz
# chirps-v2.0.1984.02.08.tif.gz
# chirps-v2.0.1984.02.09.tif.gz
# chirps-v2.0.1984.02.10.tif.gz
# chirps-v2.0.1984.02.11.tif.gz
# chirps-v2.0.1984.02.12.tif.gz
# chirps-v2.0.1984.02.13.tif.gz
# chirps-v2.0.1984.02.14.tif.gz
# chirps-v2.0.1984.02.15.tif.gz
# chirps-v2.0.1984.02.16.tif.gz
# chirps-v2.0.1984.02.17.tif.gz
# chirps-v2.0.1984.02.18.tif.gz
# chirps-v2.0.1984.02.19.tif.gz
# chirps-v2.0.1984.02.20.tif.gz
# chirps-v2.0.1984.02.21.tif.gz
# chirps-v2.0.1984.02.22.tif.gz
# chirps-v2.0.1984.02.23.tif.gz
# chirps-v2.0.1984.02.24.tif.gz
# chirps-v2.0.1984.02.25.tif.gz
# chirps-v2.0.1984.02.26.tif.gz
# chirps-v2.0.1984.02.27.tif.gz
# chirps-v2.0.1984.02.28.tif.gz
# chirps-v2.0.1984.02.29.tif.gz
# NOk
# NOk
# chirps-v2.0.1984.03.01.tif.gz
# chirps-v2.0.1984.03.02.tif.gz
# chirps-v2.0.1984.03.03.tif.gz
# chirps-v2.0.1984.03.04.tif.gz
# chirps-v2.0.1984.03.05.tif.gz
# chirps-v2.0.1984.03.06.tif.gz
# chirps-v2.0.1984.03.07.tif.gz
# chirps-v2.0.1984.03.08.tif.gz
# chirps-v2.0.1984.03.09.tif.gz
# chirps-v2.0.1984.03.10.tif.gz
# chirps-v2.0.1984.03.11.tif.gz
# chirps-v2.0.1984.03.12.tif.gz
# chirps-v2.0.1984.03.13.tif.gz
# chirps-v2.0.1984.03.14.tif.gz
# chirps-v2.0.1984.03.15.tif.gz
# chirps-v2.0.1984.03.16.tif.gz
# chirps-v2.0.1984.03.17.tif.gz
# chirps-v2.0.1984.03.18.tif.gz
# chirps-v2.0.1984.03.19.tif.gz
# chirps-v2.0.1984.03.20.tif.gz
# chirps-v2.0.1984.03.21.tif.gz
# chirps-v2.0.1984.03.22.tif.gz
# chirps-v2.0.1984.03.23.tif.gz
# chirps-v2.0.1984.03.24.tif.gz
# chirps-v2.0.1984.03.25.tif.gz
# chirps-v2.0.1984.03.26.tif.gz
# chirps-v2.0.1984.03.27.tif.gz
# chirps-v2.0.1984.03.28.tif.gz
# chirps-v2.0.1984.03.29.tif.gz
# chirps-v2.0.1984.03.30.tif.gz
# chirps-v2.0.1984.03.31.tif.gz
# chirps-v2.0.1984.04.01.tif.gz
# chirps-v2.0.1984.04.02.tif.gz
# chirps-v2.0.1984.04.03.tif.gz
# chirps-v2.0.1984.04.04.tif.gz
# chirps-v2.0.1984.04.05.tif.gz
# chirps-v2.0.1984.04.06.tif.gz
# chirps-v2.0.1984.04.07.tif.gz
# chirps-v2.0.1984.04.08.tif.gz
# chirps-v2.0.1984.04.09.tif.gz
# chirps-v2.0.1984.04.10.tif.gz
# chirps-v2.0.1984.04.11.tif.gz
# chirps-v2.0.1984.04.12.tif.gz
# chirps-v2.0.1984.04.13.tif.gz
# chirps-v2.0.1984.04.14.tif.gz
# chirps-v2.0.1984.04.15.tif.gz
# chirps-v2.0.1984.04.16.tif.gz
# chirps-v2.0.1984.04.17.tif.gz
# chirps-v2.0.1984.04.18.tif.gz
# chirps-v2.0.1984.04.19.tif.gz
# chirps-v2.0.1984.04.20.tif.gz
# chirps-v2.0.1984.04.21.tif.gz
# chirps-v2.0.1984.04.22.tif.gz
# chirps-v2.0.1984.04.23.tif.gz
# chirps-v2.0.1984.04.24.tif.gz
# chirps-v2.0.1984.04.25.tif.gz
# chirps-v2.0.1984.04.26.tif.gz
# chirps-v2.0.1984.04.27.tif.gz
# chirps-v2.0.1984.04.28.tif.gz
# chirps-v2.0.1984.04.29.tif.gz
# chirps-v2.0.1984.04.30.tif.gz
# NOk
# chirps-v2.0.1984.05.01.tif.gz
# chirps-v2.0.1984.05.02.tif.gz
# chirps-v2.0.1984.05.03.tif.gz
# chirps-v2.0.1984.05.04.tif.gz
# chirps-v2.0.1984.05.05.tif.gz
# chirps-v2.0.1984.05.06.tif.gz
# chirps-v2.0.1984.05.07.tif.gz
# chirps-v2.0.1984.05.08.tif.gz
# chirps-v2.0.1984.05.09.tif.gz
# chirps-v2.0.1984.05.10.tif.gz
# chirps-v2.0.1984.05.11.tif.gz
# chirps-v2.0.1984.05.12.tif.gz
# chirps-v2.0.1984.05.13.tif.gz
# chirps-v2.0.1984.05.14.tif.gz
# chirps-v2.0.1984.05.15.tif.gz
# chirps-v2.0.1984.05.16.tif.gz
# chirps-v2.0.1984.05.17.tif.gz
# chirps-v2.0.1984.05.18.tif.gz
# chirps-v2.0.1984.05.19.tif.gz
# chirps-v2.0.1984.05.20.tif.gz
# chirps-v2.0.1984.05.21.tif.gz
# chirps-v2.0.1984.05.22.tif.gz
# chirps-v2.0.1984.05.23.tif.gz
# chirps-v2.0.1984.05.24.tif.gz
# chirps-v2.0.1984.05.25.tif.gz
# chirps-v2.0.1984.05.26.tif.gz
# chirps-v2.0.1984.05.27.tif.gz
# chirps-v2.0.1984.05.28.tif.gz
# chirps-v2.0.1984.05.29.tif.gz
# chirps-v2.0.1984.05.30.tif.gz
# chirps-v2.0.1984.05.31.tif.gz
# chirps-v2.0.1984.06.01.tif.gz
# chirps-v2.0.1984.06.02.tif.gz
# chirps-v2.0.1984.06.03.tif.gz
# chirps-v2.0.1984.06.04.tif.gz
# chirps-v2.0.1984.06.05.tif.gz
# chirps-v2.0.1984.06.06.tif.gz
# chirps-v2.0.1984.06.07.tif.gz
# chirps-v2.0.1984.06.08.tif.gz
# chirps-v2.0.1984.06.09.tif.gz
# chirps-v2.0.1984.06.10.tif.gz
# chirps-v2.0.1984.06.11.tif.gz
# chirps-v2.0.1984.06.12.tif.gz
# chirps-v2.0.1984.06.13.tif.gz
# chirps-v2.0.1984.06.14.tif.gz
# chirps-v2.0.1984.06.15.tif.gz
# chirps-v2.0.1984.06.16.tif.gz
# chirps-v2.0.1984.06.17.tif.gz
# chirps-v2.0.1984.06.18.tif.gz
# chirps-v2.0.1984.06.19.tif.gz
# chirps-v2.0.1984.06.20.tif.gz
# chirps-v2.0.1984.06.21.tif.gz
# chirps-v2.0.1984.06.22.tif.gz
# chirps-v2.0.1984.06.23.tif.gz
# chirps-v2.0.1984.06.24.tif.gz
# chirps-v2.0.1984.06.25.tif.gz
# chirps-v2.0.1984.06.26.tif.gz
# chirps-v2.0.1984.06.27.tif.gz
# chirps-v2.0.1984.06.28.tif.gz
# chirps-v2.0.1984.06.29.tif.gz
# chirps-v2.0.1984.06.30.tif.gz
# NOk
# chirps-v2.0.1984.07.01.tif.gz
# chirps-v2.0.1984.07.02.tif.gz
# chirps-v2.0.1984.07.03.tif.gz
# chirps-v2.0.1984.07.04.tif.gz
# chirps-v2.0.1984.07.05.tif.gz
# chirps-v2.0.1984.07.06.tif.gz
# chirps-v2.0.1984.07.07.tif.gz
# chirps-v2.0.1984.07.08.tif.gz
# chirps-v2.0.1984.07.09.tif.gz
# chirps-v2.0.1984.07.10.tif.gz
# chirps-v2.0.1984.07.11.tif.gz
# chirps-v2.0.1984.07.12.tif.gz
# chirps-v2.0.1984.07.13.tif.gz
# chirps-v2.0.1984.07.14.tif.gz
# chirps-v2.0.1984.07.15.tif.gz
# chirps-v2.0.1984.07.16.tif.gz
# chirps-v2.0.1984.07.17.tif.gz
# chirps-v2.0.1984.07.18.tif.gz
# chirps-v2.0.1984.07.19.tif.gz
# chirps-v2.0.1984.07.20.tif.gz
# chirps-v2.0.1984.07.21.tif.gz
# chirps-v2.0.1984.07.22.tif.gz
# chirps-v2.0.1984.07.23.tif.gz
# chirps-v2.0.1984.07.24.tif.gz
# chirps-v2.0.1984.07.25.tif.gz
# chirps-v2.0.1984.07.26.tif.gz
# chirps-v2.0.1984.07.27.tif.gz
# chirps-v2.0.1984.07.28.tif.gz
# chirps-v2.0.1984.07.29.tif.gz
# chirps-v2.0.1984.07.30.tif.gz
