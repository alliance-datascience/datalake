# %%
 # !pip install rioxarray "xarray[complete]" geopandas  "dask[complete]"

# %%
import rioxarray as rx
import pandas as pd
import boto3
import xarray as xr
import glob
import shutil
import os
import zarr
import s3fs
import geopandas as gpd
from dask.diagnostics import ProgressBar

# %%
pathS3 = "s3://climate-action-datalake/zone=raw/source=chirps"
localPath = 'data/toZarr/*.nc'

# %%
chirts = xr.open_dataset('data/toZarr/19910626.nc')

# %%
chirts
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 7200, lat: 2600, time: 1, band: 1)
# Coordinates:
#   * lon      (lon) float64 -180.0 -179.9 -179.9 -179.8 ... 179.9 179.9 180.0
#   * lat      (lat) float64 69.97 69.92 69.87 69.82 ... -59.88 -59.93 -59.98
#   * time     (time) datetime64[ns] 1991-06-26
# Dimensions without coordinates: band
# Data variables:
#     tmin     (time, band, lat, lon) float32 ...

# %%
chirts = chirts[['time','band','lat','lon','tmin']]

# %%
def convertKelvinCelsius(k):
    c = k - 273.15
    return c

# %%
allFiles = xr.open_mfdataset(localPath,parallel=True,chunks={'time': 100})

# %%
allFiles = allFiles[['time','band','lat','lon','tmin']]

# %%
print('Hola mundo')
# Out:
# Hola mundo

# %%
#allFiles = allFiles.apply(convertKelvinCelsius)

# %%
allFiles
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 12419, band: 1, lat: 2600, lon: 7200)
# Coordinates:
#   * time     (time) datetime64[ns] 1983-01-01 1983-01-02 ... 2016-12-31
#   * band     (band) int64 0
#   * lat      (lat) float64 69.97 69.92 69.87 69.82 ... -59.88 -59.93 -59.98
#   * lon      (lon) float64 -180.0 -179.9 -179.9 -179.8 ... 179.9 179.9 180.0
# Data variables:
#     tmin     (time, band, lat, lon) float32 dask.array<chunksize=(1, 1, 2600, 7200), meta=np.ndarray>

# %%
compressor = zarr.Blosc(cname='lz4', clevel= 1, shuffle=False)
from numcodecs import blosc
blosc.set_nthreads(8) 
encoding = {vname: {'compressor': compressor,'chunks': (1,1,2000,7200)} for vname in allFiles.data_vars}
# encoding = {vname: {'chunks': (1,1,2000,7200)} for vname in allFiles.data_vars}
#encoding = {vname: {'compressor': None,'chunks': (1,1,2000,7200)} for vname in allFiles.data_vars}

# %%
s3 = s3fs.S3FileSystem()
store = s3fs.S3Map(root="s3://climate-action-datalake/zone=raw/source=chirps/variable=precipitation", s3=s3, check=False)

# %%
with ProgressBar():
    result = allFiles.to_zarr('data/tmin.zarr', encoding=encoding, consolidated=True,compute=False)

# %%
result
# Out:
# Delayed('_finalize_store-c2737ef5-6d42-499b-b62e-16334ff8ef5b')

# %%
with ProgressBar():
    result.compute(scheduler='processes')
# Out:
# [########################################] | 100% Completed | 2hr 56m

# %%
print("He finalizado")
# Out:
# He finalizado
